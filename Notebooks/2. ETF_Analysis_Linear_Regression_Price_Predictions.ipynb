# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# For Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# For graph plotting style
plt.style.use('seaborn-v0_8-whitegrid')

#No System Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
Ticker = "QQQ" # Insert the ETF Ticker that you wish to test Here, e.g. "QQQE"

# %%
ETF_filename_no_features = f"../Resources/Raw_Files/YFINANCE/{Ticker}_1d_data.csv"
ETF_filename_features = f"../Resources/Featured_Files/YFINANCE/{Ticker}_1d_features.csv"

feat_df = pd.read_csv(ETF_filename_features)
no_feat_df = pd.read_csv(ETF_filename_no_features)

# %%
no_feat_df.shape, feat_df.shape,
# Out:
# ((1507, 9), (1507, 32))

# %%
feat_df.isnull().sum(), no_feat_df.isnull().sum()
# Out:
# (Date                       0
#  Ticker                     0
#  Open                       0
#  High                       0
#  Low                        0
#  Close                      0
#  Volume                     0
#  Dividends                  0
#  Stock Splits               0
#  Capital Gains              0
#  Price_Movement             0
#  Price_Movement_Pct         0
#  Year                       0
#  Month                      0
#  Day                        0
#  Day_of_Year                0
#  Day_of_Week                0
#  quarter                    0
#  Close_lag1                 0
#  Close_lag3                 0
#  Close_lag5                 0
#  Close_lag7                 0
#  Close_lag14                0
#  Close_lag21                0
#  Close_lag28                0
#  Close_lag365               0
#  Month_Sin                  0
#  Month_Cos                  0
#  Dayofweek_Sin              0
#  Dayofweek_Cos              0
#  Price_Movement_Category    0
#  Price_Movement_Code        0
#  dtype: int64,
#  Date             0
#  Open             0
#  High             0
#  Low              0
#  Close            0
#  Volume           0
#  Dividends        0
#  Stock Splits     0
#  Capital Gains    0
#  dtype: int64)

# %%
econ_data_df = pd.read_csv(r"../Resources/Raw_Files/FRED/fred_macro_data.csv")

# %%
merged_feat = feat_df.merge(econ_data_df, on="Date", how="inner")  
merged_no_feat = no_feat_df.merge(econ_data_df, on="Date", how="inner")

# %%
merged_feat.head(), merged_no_feat.head()
# Out:
# (         Date Ticker        Open        High         Low       Close  \
#  0  2020-01-03    QQQ  205.820530  207.914436  205.801227  206.669662
#  1  2020-01-06    QQQ  205.048539  208.030183  204.797662  208.001236
#  2  2020-01-07    QQQ  208.078433  208.560901  207.316142  207.972290
#  3  2020-01-08    QQQ  207.943356  210.490782  207.615282  209.535492
#  4  2020-01-09    QQQ  211.262770  211.716291  210.075905  211.311020
#
#       Volume  Dividends  Stock Splits  Capital Gains  ...  \
#  0  27518900        0.0           0.0            0.0  ...
#  1  21655300        0.0           0.0            0.0  ...
#  2  22139300        0.0           0.0            0.0  ...
#  3  26397300        0.0           0.0            0.0  ...
#  4  23547000        0.0           0.0            0.0  ...
#
#     U_Mich_Consumer_Sentiment  Chicago_Fed_National_Activity_Index  \
#  0                       99.8                                -0.25
#  1                       99.8                                -0.25
#  2                       99.8                                -0.25
#  3                       99.8                                -0.25
#  4                       99.8                                -0.25
#
#     CBOE_Volatility_Index (VIX)  Chicago_Fed_National_Financial_Conditions  \
#  0                        14.02                                   -0.56878
#  1                        13.85                                   -0.56878
#  2                        13.79                                   -0.56878
#  3                        13.45                                   -0.56878
#  4                        12.54                                   -0.56878
#
#     Equity_Vol_Tracker:_Broad Macro  10Y-3M_Treasury_Spread  \
#  0                          5.66965                    0.28
#  1                          5.66965                    0.25
#  2                          5.66965                    0.29
#  3                          5.66965                    0.33
#  4                          5.66965                    0.31
#
#     Moodys_BAA_Corporate_Bond_Yield  Capacity_Utilization:_Manufacturing  \
#  0                             1.99                                208.0
#  1                             2.02                                208.0
#  2                             2.03                                208.0
#  3                             2.05                                208.0
#  4                             2.03                                208.0
#
#     1-Month_Treasury_Bill  WTI_Crude_Oil_Price
#  0                   1.52                63.00
#  1                   1.54                63.27
#  2                   1.52                62.70
#  3                   1.50                59.65
#  4                   1.53                59.56
#
#  [5 rows x 78 columns],
#           Date        Open        High         Low       Close    Volume  \
#  0  2020-01-03  205.820530  207.914436  205.801227  206.669662  27518900
#  1  2020-01-06  205.048539  208.030183  204.797662  208.001236  21655300
#  2  2020-01-07  208.078433  208.560901  207.316142  207.972290  22139300
#  3  2020-01-08  207.943356  210.490782  207.615282  209.535492  26397300
#  4  2020-01-09  211.262770  211.716291  210.075905  211.311020  23547000
#
#     Dividends  Stock Splits  Capital Gains        GDP  ...  \
#  0        0.0           0.0            0.0  21751.238  ...
#  1        0.0           0.0            0.0  21751.238  ...
#  2        0.0           0.0            0.0  21751.238  ...
#  3        0.0           0.0            0.0  21751.238  ...
#  4        0.0           0.0            0.0  21751.238  ...
#
#     U_Mich_Consumer_Sentiment  Chicago_Fed_National_Activity_Index  \
#  0                       99.8                                -0.25
#  1                       99.8                                -0.25
#  2                       99.8                                -0.25
#  3                       99.8                                -0.25
#  4                       99.8                                -0.25
#
#     CBOE_Volatility_Index (VIX)  Chicago_Fed_National_Financial_Conditions  \
#  0                        14.02                                   -0.56878
#  1                        13.85                                   -0.56878
#  2                        13.79                                   -0.56878
#  3                        13.45                                   -0.56878
#  4                        12.54                                   -0.56878
#
#     Equity_Vol_Tracker:_Broad Macro  10Y-3M_Treasury_Spread  \
#  0                          5.66965                    0.28
#  1                          5.66965                    0.25
#  2                          5.66965                    0.29
#  3                          5.66965                    0.33
#  4                          5.66965                    0.31
#
#     Moodys_BAA_Corporate_Bond_Yield  Capacity_Utilization:_Manufacturing  \
#  0                             1.99                                208.0
#  1                             2.02                                208.0
#  2                             2.03                                208.0
#  3                             2.05                                208.0
#  4                             2.03                                208.0
#
#     1-Month_Treasury_Bill  WTI_Crude_Oil_Price
#  0                   1.52                63.00
#  1                   1.54                63.27
#  2                   1.52                62.70
#  3                   1.50                59.65
#  4                   1.53                59.56
#
#  [5 rows x 55 columns])

# %%
merged_no_feat.info(), merged_feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       1506 non-null   object
#  1   Open                                       1506 non-null   float64
#  2   High                                       1506 non-null   float64
#  3   Low                                        1506 non-null   float64
#  4   Close                                      1506 non-null   float64
#  5   Volume                                     1506 non-null   int64
#  6   Dividends                                  1506 non-null   float64
#  7   Stock Splits                               1506 non-null   float64
#  8   Capital Gains                              1506 non-null   float64
#  9   GDP                                        1506 non-null   float64
#  10  CPI_Inflation                              1506 non-null   float64
#  11  Average_price_of_eggs                      1506 non-null   float64
#  12  Average_price_of_electricity               1506 non-null   float64
#  13  Leading_Index_for_US                       1506 non-null   float64
#  14  NBER_Recession_Indicator                   1506 non-null   float64
#  15  Producer_Price_Index                       1506 non-null   float64
#  16  5-Year_Breakeven_Inflation                 1506 non-null   float64
#  17  Natural_Rate__of_Unemployment_(est.)       1506 non-null   float64
#  18  Civilian_Labor_Force_Participation         1506 non-null   float64
#  19  BBB_Corporate_Spread                       1506 non-null   float64
#  20  Real_Gross_Domestic_Product                1506 non-null   float64
#  21  Personal_Consumption_Expenditures          1506 non-null   float64
#  22  Industrial_Production_Index                1506 non-null   float64
#  23  Recession_Probabilities                    1506 non-null   float64
#  24  Core_CPI_(ex_Food/Energy)                  1506 non-null   float64
#  25  10-Year_Breakeven_Inflation                1506 non-null   float64
#  26  10-Year_TIPS_Yield                         1506 non-null   float64
#  27  10-Year_Treasury_Yield                     1506 non-null   float64
#  28  Unemployment_Rate                          1506 non-null   float64
#  29  Nonfarm_Payrolls                           1506 non-null   float64
#  30  Job_Openings_(JOLTS)                       1506 non-null   float64
#  31  Effective_Fed_Funds_Rate                   1506 non-null   float64
#  32  2-Year_Treasury_Yield                      1506 non-null   float64
#  33  10Y-2Y_Treasury_Spread                     1506 non-null   float64
#  34  High_Yield_OAS                             1506 non-null   float64
#  35  Equity_Mkt_Vol:_Macro_News_Tracker         1506 non-null   float64
#  36  Equity_Market_Uncertainty_Index            1506 non-null   float64
#  37  U_Mich_Inflation_Expectations              1506 non-null   float64
#  38  Housing_Starts:_Total                      1506 non-null   float64
#  39  New_Private_Housing_Units_Authorized       1506 non-null   float64
#  40  30-Year_Fixed_Mortgage_Rate                1506 non-null   float64
#  41  M2_Money_Stock                             1506 non-null   float64
#  42  ON_RRP_(Reverse_Repo)_Balance              1506 non-null   float64
#  43  Monetary_Base                              1506 non-null   float64
#  44  Commercial_&_Industrial_Loans              1506 non-null   float64
#  45  U_Mich_Consumer_Sentiment                  1506 non-null   float64
#  46  Chicago_Fed_National_Activity_Index        1506 non-null   float64
#  47  CBOE_Volatility_Index (VIX)                1506 non-null   float64
#  48  Chicago_Fed_National_Financial_Conditions  1506 non-null   float64
#  49  Equity_Vol_Tracker:_Broad Macro            1506 non-null   float64
#  50  10Y-3M_Treasury_Spread                     1506 non-null   float64
#  51  Moodys_BAA_Corporate_Bond_Yield            1506 non-null   float64
#  52  Capacity_Utilization:_Manufacturing        1506 non-null   float64
#  53  1-Month_Treasury_Bill                      1506 non-null   float64
#  54  WTI_Crude_Oil_Price                        1506 non-null   float64
# dtypes: float64(53), int64(1), object(1)
# memory usage: 647.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 78 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       1506 non-null   object
#  1   Ticker                                     1506 non-null   object
#  2   Open                                       1506 non-null   float64
#  3   High                                       1506 non-null   float64
#  4   Low                                        1506 non-null   float64
#  5   Close                                      1506 non-null   float64
#  6   Volume                                     1506 non-null   int64
#  7   Dividends                                  1506 non-null   float64
#  8   Stock Splits                               1506 non-null   float64
#  9   Capital Gains                              1506 non-null   float64
#  10  Price_Movement                             1506 non-null   float64
#  11  Price_Movement_Pct                         1506 non-null   float64
#  12  Year                                       1506 non-null   int64
#  13  Month                                      1506 non-null   int64
#  14  Day                                        1506 non-null   int64
#  15  Day_of_Year                                1506 non-null   int64
#  16  Day_of_Week                                1506 non-null   int64
#  17  quarter                                    1506 non-null   int64
#  18  Close_lag1                                 1506 non-null   float64
#  19  Close_lag3                                 1506 non-null   float64
#  20  Close_lag5                                 1506 non-null   float64
#  21  Close_lag7                                 1506 non-null   float64
#  22  Close_lag14                                1506 non-null   float64
#  23  Close_lag21                                1506 non-null   float64
#  24  Close_lag28                                1506 non-null   float64
#  25  Close_lag365                               1506 non-null   float64
#  26  Month_Sin                                  1506 non-null   float64
#  27  Month_Cos                                  1506 non-null   float64
#  28  Dayofweek_Sin                              1506 non-null   float64
#  29  Dayofweek_Cos                              1506 non-null   float64
#  30  Price_Movement_Category                    1506 non-null   object
#  31  Price_Movement_Code                        1506 non-null   int64
#  32  GDP                                        1506 non-null   float64
#  33  CPI_Inflation                              1506 non-null   float64
#  34  Average_price_of_eggs                      1506 non-null   float64
#  35  Average_price_of_electricity               1506 non-null   float64
#  36  Leading_Index_for_US                       1506 non-null   float64
#  37  NBER_Recession_Indicator                   1506 non-null   float64
#  38  Producer_Price_Index                       1506 non-null   float64
#  39  5-Year_Breakeven_Inflation                 1506 non-null   float64
#  40  Natural_Rate__of_Unemployment_(est.)       1506 non-null   float64
#  41  Civilian_Labor_Force_Participation         1506 non-null   float64
#  42  BBB_Corporate_Spread                       1506 non-null   float64
#  43  Real_Gross_Domestic_Product                1506 non-null   float64
#  44  Personal_Consumption_Expenditures          1506 non-null   float64
#  45  Industrial_Production_Index                1506 non-null   float64
#  46  Recession_Probabilities                    1506 non-null   float64
#  47  Core_CPI_(ex_Food/Energy)                  1506 non-null   float64
#  48  10-Year_Breakeven_Inflation                1506 non-null   float64
#  49  10-Year_TIPS_Yield                         1506 non-null   float64
#  50  10-Year_Treasury_Yield                     1506 non-null   float64
#  51  Unemployment_Rate                          1506 non-null   float64
#  52  Nonfarm_Payrolls                           1506 non-null   float64
#  53  Job_Openings_(JOLTS)                       1506 non-null   float64
#  54  Effective_Fed_Funds_Rate                   1506 non-null   float64
#  55  2-Year_Treasury_Yield                      1506 non-null   float64
#  56  10Y-2Y_Treasury_Spread                     1506 non-null   float64
#  57  High_Yield_OAS                             1506 non-null   float64
#  58  Equity_Mkt_Vol:_Macro_News_Tracker         1506 non-null   float64
#  59  Equity_Market_Uncertainty_Index            1506 non-null   float64
#  60  U_Mich_Inflation_Expectations              1506 non-null   float64
#  61  Housing_Starts:_Total                      1506 non-null   float64
#  62  New_Private_Housing_Units_Authorized       1506 non-null   float64
#  63  30-Year_Fixed_Mortgage_Rate                1506 non-null   float64
#  64  M2_Money_Stock                             1506 non-null   float64
#  65  ON_RRP_(Reverse_Repo)_Balance              1506 non-null   float64
#  66  Monetary_Base                              1506 non-null   float64
#  67  Commercial_&_Industrial_Loans              1506 non-null   float64
#  68  U_Mich_Consumer_Sentiment                  1506 non-null   float64
#  69  Chicago_Fed_National_Activity_Index        1506 non-null   float64
#  70  CBOE_Volatility_Index (VIX)                1506 non-null   float64
#  71  Chicago_Fed_National_Financial_Conditions  1506 non-null   float64
#  72  Equity_Vol_Tracker:_Broad Macro            1506 non-null   float64
#  73  10Y-3M_Treasury_Spread                     1506 non-null   float64
#  74  Moodys_BAA_Corporate_Bond_Yield            1506 non-null   float64
#  75  Capacity_Utilization:_Manufacturing        1506 non-null   float64
#  76  1-Month_Treasury_Bill                      1506 non-null   float64
#  77  WTI_Crude_Oil_Price                        1506 non-null   float64
# dtypes: float64(67), int64(8), object(3)
# memory usage: 917.8+ KB
# (None, None)

# %%
drop_list_feat =merged_feat.select_dtypes(include=['object']).columns.to_list()
drop_list_no_feat = merged_no_feat.select_dtypes(include=['object']).columns.to_list()

# %%
drop_list_feat, drop_list_no_feat
# Out:
# (['Date', 'Ticker', 'Price_Movement_Category'], ['Date'])

# %%
merged_no_feat = merged_no_feat.drop(drop_list_no_feat,axis=1)
merged_feat = merged_feat.drop(drop_list_feat,axis=1)

# %%
merged_no_feat = merged_no_feat.fillna(0)
merged_feat = merged_feat.fillna(0)

# %%
X_no_feat = merged_no_feat.drop(['Close','Open', 'High', 'Low'], axis=1)
Y_no_feat = merged_no_feat['Close']

X_feat = merged_feat.drop(['Close','Open', 'High', 'Low'], axis=1)
Y_feat = merged_feat['Close']

# %%
X_train_no_feat, X_test_no_feat, y_train_no_feat, y_test_no_feat = train_test_split(
    X_no_feat, 
    Y_no_feat, 
    test_size=0.2, 
    random_state=42
)

print(f"Training on {len(X_train_no_feat)} ETF prices - no feature engineering")
print(f"Testing on {len(X_test_no_feat)} ETF prices - no feature engineering")

X_train_feat, X_test_feat, y_train_feat, y_test_feat = train_test_split(
    X_feat, 
    Y_feat, 
    test_size=0.2, 
    random_state=42
)

print(f"\nTraining on {len(X_train_feat)} ETF prices - with feature engineering")
print(f"Testing on {len(X_test_feat)} ETF prices - with feature engineering")
# Out:
# Training on 1204 ETF prices - no feature engineering
# Testing on 302 ETF prices - no feature engineering
#
# Training on 1204 ETF prices - with feature engineering
# Testing on 302 ETF prices - with feature engineering

# %%
# Train the regression model
model_no_feat = LinearRegression()
model_no_feat.fit(X_train_no_feat, y_train_no_feat)

model_feat = LinearRegression()
model_feat.fit(X_train_feat, y_train_feat)

# Make predictions
y_pred_no_feat = model_no_feat.predict(X_test_no_feat)
y_pred_feat = model_feat.predict(X_test_feat)

# %%
y_pred_no_feat, y_pred_feat
# Out:
# (array([333.85902052, 459.73246867, 344.09653093, 314.02077784,
#         371.80817172, 466.95348837, 273.99084158, 432.03970395,
#         262.74072818, 451.42316188, 593.11310931, 617.29897885,
#         309.41602612, 357.37937692, 304.41099553, 442.01322359,
#         298.30852657, 363.43174454, 386.48185413, 382.47993115,
#         374.42440214, 461.28792104, 322.26684898, 337.55449921,
#         358.92974289, 614.93531045, 509.95370994, 351.27668304,
#         600.37064112, 604.74529603, 362.78821323, 569.63348161,
#         509.31338635, 261.27061845, 336.58974852, 379.38879912,
#         305.39047953, 266.18540257, 467.84582863, 513.1477692 ,
#         468.19604003, 295.47183403, 558.23328962, 197.34427981,
#         471.44663827, 361.0233082 , 438.25702302, 296.52635308,
#         335.70465347, 143.83082109, 283.29234485, 360.70163118,
#         305.92291836, 360.1569579 , 574.18458626, 292.81511555,
#         295.9557753 , 361.05478298, 277.91237834, 465.57499496,
#         140.02138093, 203.2917894 , 301.98780248, 466.53530817,
#         557.69183484, 298.95775809, 378.88831921, 314.56853398,
#         436.1434234 , 241.12804606, 618.78026701, 327.84096134,
#         448.95460508, 508.71343218, 440.16441962, 200.19280047,
#         337.11092929, 318.94424507, 600.4521144 , 307.94684285,
#         451.56462139, 309.89703351, 360.55402886, 229.10430801,
#         230.25213771, 303.00856078, 344.14530727, 273.00069665,
#         186.29624682, 342.9068109 , 339.82806012, 280.47216147,
#         537.15728753, 296.42856598, 324.57722177, 351.35660156,
#         375.97058312, 494.82649232, 534.34932996, 292.68103718,
#         431.50793211, 371.57539096, 613.60599106, 461.8472962 ,
#         269.72026144, 378.23389415, 513.38142654, 468.21785458,
#         196.78945019, 193.52556735, 495.32110078, 474.50413277,
#         226.06598314, 364.64326726, 359.57986167, 617.68133343,
#         326.67296058, 440.17973203, 589.10158494, 356.63376453,
#         360.3147367 , 407.56785459, 229.07128305, 622.86425007,
#         285.34031714, 488.7232081 , 311.13188229, 306.70400456,
#         293.37062509, 285.99043128, 277.48414728, 609.76376993,
#         463.75140104, 211.94596467, 282.24904193, 557.21114581,
#         305.8798766 , 382.55192576, 205.24939012, 360.4320283 ,
#         320.29211589, 412.55473142, 591.77847729, 366.73656505,
#         308.79669415, 359.30679212, 323.93744733, 355.20835806,
#         356.50972444, 467.22901304, 266.07051161, 271.33964946,
#         311.26390533, 293.4340029 , 371.43959215, 418.98564551,
#         508.97738914, 363.58492167, 313.06266109, 306.12108234,
#         438.21940443, 412.23653992, 339.09340388, 215.56204796,
#         364.99091087, 284.03545102, 270.11950406, 351.75496176,
#         225.29253504, 238.08204512, 343.66185517, 505.42995231,
#         293.3472229 , 430.02826915, 287.72520581, 367.13572786,
#         438.98615742, 261.73494134, 245.82182217, 284.38071659,
#         309.63496261, 292.30017625, 359.78924772, 450.18435436,
#         420.13952942, 329.91487754, 507.87171468, 226.98834987,
#         301.16804474, 259.96806139, 296.57421999, 367.56511409,
#         267.22810084, 343.17899722, 367.46884932, 337.3914473 ,
#         269.84985565, 513.75673489, 333.10712778, 265.09627928,
#         371.31523058, 432.51612312, 360.25360311, 350.53627202,
#         399.75482989, 512.05226645, 334.61212008, 351.43551483,
#         484.62516977, 466.76564191, 268.86550093, 292.53649469,
#         335.85856227, 300.19523435, 181.2969875 , 265.24765462,
#         303.97084923, 360.74402894, 535.36770169, 308.16140486,
#         358.92387347, 488.23468684, 380.09071583, 270.33907402,
#         490.07636686, 355.34450755, 327.50552183, 412.17435776,
#         288.79586202, 334.78849246, 228.68578876, 173.09411213,
#         618.29714063, 369.68647566, 377.53049528, 309.45327064,
#         354.24817338, 379.56327143, 414.33878309, 317.87742284,
#         362.53605732, 527.78032452, 318.93241789, 508.68836895,
#         276.68039497, 365.18076575, 323.43872828, 226.60139074,
#         488.44690134, 302.39964811, 620.62739982, 278.4852228 ,
#         617.90774295, 382.74960759, 418.8153899 , 322.1058519 ,
#         269.85348838, 462.93176641, 362.37625006, 441.72578125,
#         606.32365533, 611.96892575, 463.00904629, 602.45319423,
#         306.9793219 , 289.41745618, 375.62915633, 596.75530811,
#         295.89998443, 516.05530369, 256.24277471, 338.06385332,
#         341.99713072, 612.89977081, 180.70930267, 307.67218656,
#         449.34278941, 362.69979061, 412.04956374, 537.64158283,
#         495.48320277, 321.02864001, 461.17757506, 368.97852819,
#         456.53628381, 313.27036929, 266.89026055, 308.32959305,
#         513.60075107, 272.29568218, 511.24093873, 206.7668336 ,
#         569.82753773, 319.94115639, 462.91552366, 220.59233291,
#         619.37167804, 369.45756592, 458.53929124, 338.89026198,
#         517.55039278, 511.77049504]),
#  array([334.0366299 , 468.5547048 , 351.28859557, 309.41932471,
#         362.62465125, 470.29114409, 264.61526545, 429.06581094,
#         264.44328912, 450.5569271 , 594.56605926, 614.98254196,
#         308.43390782, 364.18096256, 299.02329432, 437.92355833,
#         298.90399469, 372.19866522, 383.48738233, 384.72311459,
#         385.04679248, 473.02499752, 323.94532274, 330.55572081,
#         363.48968538, 603.89950654, 522.67079657, 351.98661716,
#         606.83696625, 605.8279162 , 370.67858703, 574.81070363,
#         510.90334083, 253.56769706, 339.65773386, 378.49852814,
#         308.27173528, 263.60629267, 479.2618523 , 525.17349826,
#         460.7420543 , 293.29532233, 551.2238445 , 193.66082773,
#         472.8238739 , 363.32333559, 434.42204127, 307.16037144,
#         324.34386181, 175.68130248, 277.47965392, 363.3024192 ,
#         297.16068485, 354.19253005, 575.90080584, 287.88449559,
#         285.48308438, 366.61219177, 274.72036511, 485.73228607,
#         170.880072  , 206.22569356, 307.14465963, 489.53176441,
#         555.89836617, 290.8585933 , 384.86882664, 316.29328794,
#         436.06330929, 241.71518698, 624.81402403, 332.00005334,
#         436.18778445, 512.65692163, 441.66718732, 203.48911844,
#         345.80783784, 312.52814016, 609.6993655 , 302.07945667,
#         447.97685889, 320.21372242, 356.8744291 , 238.77960186,
#         226.71364979, 302.13382579, 346.13601084, 286.79503584,
#         183.8123986 , 351.49891614, 346.32847794, 276.12518077,
#         534.57333559, 286.14471698, 317.71798829, 346.2696225 ,
#         380.50201965, 490.30697265, 530.22351347, 299.67676385,
#         421.85141905, 364.78299434, 623.25850935, 478.62454914,
#         280.62774391, 390.72928774, 519.42297561, 462.34975573,
#         198.97342314, 190.5084913 , 487.42539884, 456.11765404,
#         223.0610645 , 366.21267545, 370.35587989, 609.11565147,
#         319.03583653, 440.24922473, 596.21360538, 362.49182611,
#         352.74621841, 398.27214304, 235.60951529, 617.39804901,
#         293.40707443, 483.32586368, 312.97639334, 297.04551118,
#         286.499039  , 291.09237305, 260.83714842, 613.11558327,
#         451.86600927, 208.90623045, 277.77597508, 553.4321942 ,
#         303.7168786 , 383.73079822, 215.07843829, 348.95031729,
#         323.59795757, 414.34739598, 594.34935122, 373.65150051,
#         319.0143457 , 347.12357647, 321.90569759, 349.78962508,
#         344.65201428, 490.2498013 , 263.1204157 , 274.78893848,
#         311.05690279, 290.83020361, 376.39370197, 416.78946493,
#         519.33379699, 379.26003787, 308.15244523, 296.76463506,
#         436.608754  , 395.54292233, 330.24715537, 208.96873668,
#         368.3915603 , 288.58325384, 274.9290044 , 354.05177844,
#         224.80643885, 236.82221013, 330.61682386, 500.89102034,
#         300.4095514 , 420.85259324, 283.98120981, 367.17026595,
#         438.30922192, 269.13646118, 249.54605108, 285.25264464,
#         324.07965511, 300.6189598 , 357.61149012, 438.65520301,
#         424.75280953, 333.34852974, 485.9876081 , 226.64651215,
#         293.42279634, 254.10375551, 287.29284354, 363.96835324,
#         259.78115589, 349.49174241, 366.28660294, 322.2304103 ,
#         271.3224513 , 535.58567654, 331.91055585, 280.66147673,
#         373.68534885, 430.01205398, 367.24955525, 333.29922661,
#         384.89135009, 531.47064618, 336.34070905, 339.11792894,
#         486.43738744, 488.68237764, 269.46387138, 286.29320071,
#         331.25793253, 292.08422929, 177.23031981, 261.2275272 ,
#         294.60855501, 361.94887028, 527.53549631, 307.8227194 ,
#         348.91601823, 490.00073773, 382.53154946, 284.43561605,
#         490.67521444, 347.97206227, 330.75520884, 397.67047592,
#         280.33978496, 314.2327862 , 227.85852317, 177.27266532,
#         618.40555368, 371.17261015, 379.37102651, 309.10511575,
#         353.04095423, 376.21551345, 404.65231338, 339.54033361,
#         352.03129528, 522.90841346, 321.88145844, 527.54812874,
#         277.47817173, 366.0030754 , 320.41370768, 223.98169173,
#         484.91577346, 298.53831323, 626.61281967, 286.94767254,
#         625.41650596, 386.92460536, 427.64918016, 312.7935376 ,
#         265.03346295, 469.8757111 , 367.33014075, 428.33871956,
#         619.47631186, 622.26697184, 469.87117289, 611.2949212 ,
#         294.2461003 , 285.43464943, 366.72773147, 592.69395535,
#         304.6009062 , 518.54931081, 264.82112688, 327.57164519,
#         354.52999625, 613.82790988, 186.22293638, 308.10583351,
#         443.16090331, 369.62357468, 429.11674904, 545.08477757,
#         494.75127471, 319.07178802, 463.85040747, 381.43462873,
#         455.12931844, 314.3653189 , 269.53686653, 297.55590831,
#         532.7613646 , 282.01518209, 507.75193124, 211.27579046,
#         579.27114938, 324.54231412, 465.7909071 , 221.81757895,
#         621.5990133 , 367.95970781, 473.28214006, 352.42578396,
#         526.41761205, 516.52347971]))

# %%
# Calculate metrics
mae_no_feat = mean_absolute_error(y_test_no_feat, y_pred_no_feat)
r2_no_feat = r2_score(y_test_no_feat, y_pred_no_feat)
mae_feat = mean_absolute_error(y_test_feat, y_pred_feat)
r2_feat = r2_score(y_test_feat, y_pred_feat)

print(f"{Ticker}: Mean Absolute Error (MAE)")
print()
print(f"   Your MAE : USD {mae_no_feat:,.0f} (without feature engineering) ; USD {mae_feat:,.0f} (with feature engineering)")
print()
print("   What it means: On average, our predictions are off by this much")
print("   Goal: Lower is better!")
print()
print(f"{Ticker}: R² Score (R-squared)")
print()
print(f"   Your R² : {r2_no_feat:.1%} (without feature engineering) ; {r2_feat:.1%} (with feature engineering)")
print()
print("   What it means: How much of the ETF's Close price variation we can explain")
print("   Goal: Higher is better (100% = perfect, 0% = terrible)")
# Out:
# QQQ: Mean Absolute Error (MAE)
#
#    Your MAE : USD 7 (without feature engineering) ; USD 2 (with feature engineering)
#
#    What it means: On average, our predictions are off by this much
#    Goal: Lower is better!
#
# QQQ: R² Score (R-squared)
#
#    Your R² : 99.3% (without feature engineering) ; 99.9% (with feature engineering)
#
#    What it means: How much of the ETF's Close price variation we can explain
#    Goal: Higher is better (100% = perfect, 0% = terrible)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("{ticker}: Actual vs Predicted ETF Close Price".format(ticker=Ticker), fontsize=14, fontweight="bold")

# Left subplot: With Feature Engineering
ax1.scatter(
    y_test_feat,
    y_pred_feat,
    alpha=0.55,
    color="orange",
    edgecolors="purple",
    linewidths=0.4,
    marker="o"
)
ax1.plot(
    [y_test_feat.min(), y_test_feat.max()],
    [y_test_feat.min(), y_test_feat.max()],
    linestyle="--",
    linewidth=2,
    color="red"
)

ax1.set_xlabel("Actual ETF Close Price")
ax1.set_ylabel("Predicted ETF Close Price")
ax1.set_title("{ticker}: Model ETF Close Price Predictions (with Feature Engineering)".format(ticker=Ticker), fontweight="bold")
ax1.grid(True, alpha=0.3)

# Right subplot: Without Feature Engineering
ax2.scatter(
    y_test_no_feat,
    y_pred_no_feat,
    alpha=0.55,
    color="blue",
    edgecolors="green",
    linewidths=0.4,
    marker="o"
)
ax2.plot(
    [y_test_no_feat.min(), y_test_no_feat.max()],
    [y_test_no_feat.min(), y_test_no_feat.max()],
    linestyle="--",
    linewidth=2,
    color="red"
)

ax2.set_xlabel("Actual ETF Close Price")
ax2.set_title("{ticker}: Model ETF Close Price Predictions (No Features Engineering)".format(ticker=Ticker), fontweight="bold")
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Common x-axis
x_axis = range(len(y_test_no_feat))

# Left: No Feature Engineering
ax1.plot(x_axis, y_test_no_feat.values, 
         color="#b41f1f", linestyle='-', linewidth=2, 
         label='Actual ETF Prices', 
         )
ax1.plot(x_axis, y_pred_no_feat, 
         color="#291fb4", linestyle='--', linewidth=2,
         label='Our Predictions (No Features)', 
         )
ax1.set_xlabel('{ticker} ETF Number'.format(ticker=Ticker))
ax1.set_ylabel('Price (USD)')
ax1.set_title('{ticker}: No Feature Engineering Model'.format(ticker=Ticker))
ax1.legend()
ax1.grid(True, alpha=0.3)

# Right: With Feature Engineering
ax2.plot(x_axis, y_test_feat.values,
         color="#1fb41f", linestyle='-', linewidth=2,
         label='Actual ETF Prices')
ax2.plot(x_axis, y_pred_feat,
         color='#ff7f0e', linestyle='--', linewidth=2,
         label='Our Predictions (With Features)')
ax2.set_xlabel('{ticker} ETF Number'.format(ticker=Ticker))
ax2.set_ylabel('Price (USD)')
ax2.set_title('{ticker}: With Feature Engineering Model'.format(ticker=Ticker))
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
