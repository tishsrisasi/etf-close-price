# %%
# Usual imports for data analysis and visualization
import pandas as pd
import matplotlib.pyplot as plt

# Machine learning libraries
from sklearn.ensemble import RandomForestClassifier

# Confusion matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

#No System Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("../resources/stacked_etf_files/ticker_data_stacked1.csv")

# %%
df1.shape
# Out:
# (10549, 32)

# %%
df1.info(), df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10549 entries, 0 to 10548
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     10549 non-null  object
#  1   Ticker                   10549 non-null  object
#  2   Open                     10549 non-null  float64
#  3   High                     10549 non-null  float64
#  4   Low                      10549 non-null  float64
#  5   Close                    10549 non-null  float64
#  6   Volume                   10549 non-null  int64
#  7   Dividends                10549 non-null  float64
#  8   Stock Splits             10549 non-null  float64
#  9   Capital Gains            9042 non-null   float64
#  10  Price_Movement           10549 non-null  float64
#  11  Price_Movement_Pct       10549 non-null  float64
#  12  Year                     10549 non-null  int64
#  13  Month                    10549 non-null  int64
#  14  Day                      10549 non-null  int64
#  15  Day_of_Year              10549 non-null  int64
#  16  Day_of_Week              10549 non-null  int64
#  17  quarter                  10549 non-null  int64
#  18  Close_lag1               10549 non-null  float64
#  19  Close_lag3               10549 non-null  float64
#  20  Close_lag5               10549 non-null  float64
#  21  Close_lag7               10549 non-null  float64
#  22  Close_lag14              10549 non-null  float64
#  23  Close_lag21              10549 non-null  float64
#  24  Close_lag28              10549 non-null  float64
#  25  Close_lag365             10549 non-null  float64
#  26  Month_Sin                10549 non-null  float64
#  27  Month_Cos                10549 non-null  float64
#  28  Dayofweek_Sin            10549 non-null  float64
#  29  Dayofweek_Cos            10549 non-null  float64
#  30  Price_Movement_Category  10549 non-null  object
#  31  Price_Movement_Code      10549 non-null  int64
# dtypes: float64(21), int64(8), object(3)
# memory usage: 2.6+ MB
# (None,
#           Date Ticker        Open        High         Low       Close  \
#  0  2020-01-02    QQQ  206.881891  208.580185  206.476621  208.580185
#  1  2020-01-03    QQQ  205.820530  207.914436  205.801227  206.669662
#  2  2020-01-06    QQQ  205.048584  208.030229  204.797707  208.001282
#  3  2020-01-07    QQQ  208.078464  208.560931  207.316172  207.972321
#  4  2020-01-08    QQQ  207.943386  210.490813  207.615312  209.535522
#
#       Volume  Dividends  Stock Splits  Capital Gains  ...  Close_lag14  \
#  0  30969400        0.0           0.0            0.0  ...          0.0
#  1  27518900        0.0           0.0            0.0  ...          0.0
#  2  21655300        0.0           0.0            0.0  ...          0.0
#  3  22139300        0.0           0.0            0.0  ...          0.0
#  4  26397300        0.0           0.0            0.0  ...          0.0
#
#     Close_lag21  Close_lag28  Close_lag365  Month_Sin  Month_Cos  \
#  0          0.0          0.0           0.0        0.5   0.866025
#  1          0.0          0.0           0.0        0.5   0.866025
#  2          0.0          0.0           0.0        0.5   0.866025
#  3          0.0          0.0           0.0        0.5   0.866025
#  4          0.0          0.0           0.0        0.5   0.866025
#
#     Dayofweek_Sin  Dayofweek_Cos  Price_Movement_Category  Price_Movement_Code
#  0       0.433884      -0.900969                     high                    0
#  1      -0.433884      -0.900969                     high                    0
#  2       0.000000       1.000000                     high                    0
#  3       0.781831       0.623490                      low                    2
#  4       0.974928      -0.222521                     high                    0
#
#  [5 rows x 32 columns])

# %%
df1['Ticker_Code'], ticker_uniques = pd.factorize(df1['Ticker'])
df1['Ticker_Code'].value_counts(sort=True)
# Out:
# Ticker_Code
# 0    1507
# 1    1507
# 2    1507
# 3    1507
# 4    1507
# 5    1507
# 6    1507
# Name: count, dtype: int64

# %%
df2 = pd.read_csv(r"../resources/raw_files/fred/fred_macro_data.csv")

# %%
df2.shape
# Out:
# (2190, 47)

# %%
df2.info(), df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       2190 non-null   object
#  1   GDP                                        2190 non-null   float64
#  2   CPI_Inflation                              2190 non-null   float64
#  3   Average_price_of_eggs                      2190 non-null   float64
#  4   Average_price_of_electricity               2190 non-null   float64
#  5   Leading_Index_for_US                       2190 non-null   float64
#  6   NBER_Recession_Indicator                   2190 non-null   float64
#  7   Producer_Price_Index                       2190 non-null   float64
#  8   5-Year_Breakeven_Inflation                 2190 non-null   float64
#  9   Natural_Rate__of_Unemployment_(est.)       2190 non-null   float64
#  10  Civilian_Labor_Force_Participation         2190 non-null   float64
#  11  BBB_Corporate_Spread                       2190 non-null   float64
#  12  Real_Gross_Domestic_Product                2190 non-null   float64
#  13  Personal_Consumption_Expenditures          2190 non-null   float64
#  14  Industrial_Production_Index                2190 non-null   float64
#  15  Recession_Probabilities                    2190 non-null   float64
#  16  Core_CPI_(ex_Food/Energy)                  2190 non-null   float64
#  17  10-Year_Breakeven_Inflation                2190 non-null   float64
#  18  10-Year_TIPS_Yield                         2190 non-null   float64
#  19  10-Year_Treasury_Yield                     2190 non-null   float64
#  20  Unemployment_Rate                          2190 non-null   float64
#  21  Nonfarm_Payrolls                           2190 non-null   float64
#  22  Job_Openings_(JOLTS)                       2190 non-null   float64
#  23  Effective_Fed_Funds_Rate                   2190 non-null   float64
#  24  2-Year_Treasury_Yield                      2190 non-null   float64
#  25  10Y-2Y_Treasury_Spread                     2190 non-null   float64
#  26  High_Yield_OAS                             2190 non-null   float64
#  27  Equity_Mkt_Vol:_Macro_News_Tracker         2190 non-null   float64
#  28  Equity_Market_Uncertainty_Index            2190 non-null   float64
#  29  U_Mich_Inflation_Expectations              2190 non-null   float64
#  30  Housing_Starts:_Total                      2190 non-null   float64
#  31  New_Private_Housing_Units_Authorized       2190 non-null   float64
#  32  30-Year_Fixed_Mortgage_Rate                2190 non-null   float64
#  33  M2_Money_Stock                             2190 non-null   float64
#  34  ON_RRP_(Reverse_Repo)_Balance              2190 non-null   float64
#  35  Monetary_Base                              2190 non-null   float64
#  36  Commercial_&_Industrial_Loans              2190 non-null   float64
#  37  U_Mich_Consumer_Sentiment                  2190 non-null   float64
#  38  Chicago_Fed_National_Activity_Index        2190 non-null   float64
#  39  CBOE_Volatility_Index (VIX)                2190 non-null   float64
#  40  Chicago_Fed_National_Financial_Conditions  2190 non-null   float64
#  41  Equity_Vol_Tracker:_Broad Macro            2190 non-null   float64
#  42  10Y-3M_Treasury_Spread                     2190 non-null   float64
#  43  Moodys_BAA_Corporate_Bond_Yield            2190 non-null   float64
#  44  Capacity_Utilization:_Manufacturing        2190 non-null   float64
#  45  1-Month_Treasury_Bill                      2190 non-null   float64
#  46  WTI_Crude_Oil_Price                        2190 non-null   float64
# dtypes: float64(46), object(1)
# memory usage: 804.3+ KB
# (None,
#           Date        GDP  CPI_Inflation  Average_price_of_eggs  \
#  0  2020-01-03  21751.238        259.127                  1.461
#  1  2020-01-04  21751.238        259.127                  1.461
#  2  2020-01-05  21751.238        259.127                  1.461
#  3  2020-01-06  21751.238        259.127                  1.461
#  4  2020-01-07  21751.238        259.127                  1.461
#
#     Average_price_of_electricity  Leading_Index_for_US  \
#  0                         0.134                  1.57
#  1                         0.134                  1.57
#  2                         0.134                  1.57
#  3                         0.134                  1.57
#  4                         0.134                  1.57
#
#     NBER_Recession_Indicator  Producer_Price_Index  5-Year_Breakeven_Inflation  \
#  0                       0.0                 199.3                        1.85
#  1                       0.0                 199.3                        1.85
#  2                       0.0                 199.3                        1.85
#  3                       0.0                 199.3                        1.81
#  4                       0.0                 199.3                        1.81
#
#     Natural_Rate__of_Unemployment_(est.)  ...  U_Mich_Consumer_Sentiment  \
#  0                              4.403836  ...                       99.8
#  1                              4.403836  ...                       99.8
#  2                              4.403836  ...                       99.8
#  3                              4.403836  ...                       99.8
#  4                              4.403836  ...                       99.8
#
#     Chicago_Fed_National_Activity_Index  CBOE_Volatility_Index (VIX)  \
#  0                                -0.25                        14.02
#  1                                -0.25                        14.02
#  2                                -0.25                        14.02
#  3                                -0.25                        13.85
#  4                                -0.25                        13.79
#
#     Chicago_Fed_National_Financial_Conditions  Equity_Vol_Tracker:_Broad Macro  \
#  0                                   -0.56599                          5.66965
#  1                                   -0.56599                          5.66965
#  2                                   -0.56599                          5.66965
#  3                                   -0.56599                          5.66965
#  4                                   -0.56599                          5.66965
#
#     10Y-3M_Treasury_Spread  Moodys_BAA_Corporate_Bond_Yield  \
#  0                    0.28                             1.99
#  1                    0.28                             1.99
#  2                    0.28                             1.99
#  3                    0.25                             2.02
#  4                    0.29                             2.03
#
#     Capacity_Utilization:_Manufacturing  1-Month_Treasury_Bill  \
#  0                                208.0                   1.52
#  1                                208.0                   1.52
#  2                                208.0                   1.52
#  3                                208.0                   1.54
#  4                                208.0                   1.52
#
#     WTI_Crude_Oil_Price
#  0                63.00
#  1                63.00
#  2                63.00
#  3                63.27
#  4                62.70
#
#  [5 rows x 47 columns])

# %%
df1['Date'] = pd.to_datetime(df1['Date'], errors='coerce')
df2['Date'] = pd.to_datetime(df2['Date'], errors='coerce')

# %%
ml = df2.merge(df1, on="Date", how="inner")
ml1 = df1.copy()
ml1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10549 entries, 0 to 10548
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     10549 non-null  datetime64[ns]
#  1   Ticker                   10549 non-null  object
#  2   Open                     10549 non-null  float64
#  3   High                     10549 non-null  float64
#  4   Low                      10549 non-null  float64
#  5   Close                    10549 non-null  float64
#  6   Volume                   10549 non-null  int64
#  7   Dividends                10549 non-null  float64
#  8   Stock Splits             10549 non-null  float64
#  9   Capital Gains            9042 non-null   float64
#  10  Price_Movement           10549 non-null  float64
#  11  Price_Movement_Pct       10549 non-null  float64
#  12  Year                     10549 non-null  int64
#  13  Month                    10549 non-null  int64
#  14  Day                      10549 non-null  int64
#  15  Day_of_Year              10549 non-null  int64
#  16  Day_of_Week              10549 non-null  int64
#  17  quarter                  10549 non-null  int64
#  18  Close_lag1               10549 non-null  float64
#  19  Close_lag3               10549 non-null  float64
#  20  Close_lag5               10549 non-null  float64
#  21  Close_lag7               10549 non-null  float64
#  22  Close_lag14              10549 non-null  float64
#  23  Close_lag21              10549 non-null  float64
#  24  Close_lag28              10549 non-null  float64
#  25  Close_lag365             10549 non-null  float64
#  26  Month_Sin                10549 non-null  float64
#  27  Month_Cos                10549 non-null  float64
#  28  Dayofweek_Sin            10549 non-null  float64
#  29  Dayofweek_Cos            10549 non-null  float64
#  30  Price_Movement_Category  10549 non-null  object
#  31  Price_Movement_Code      10549 non-null  int64
#  32  Ticker_Code              10549 non-null  int64
# dtypes: datetime64[ns](1), float64(21), int64(9), object(2)
# memory usage: 2.7+ MB

# %%
ml.set_index('Date', inplace=True)
ml1.set_index('Date', inplace=True)
ml.info(), ml1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10542 entries, 2020-01-03 to 2025-12-30
# Data columns (total 78 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GDP                                        10542 non-null  float64
#  1   CPI_Inflation                              10542 non-null  float64
#  2   Average_price_of_eggs                      10542 non-null  float64
#  3   Average_price_of_electricity               10542 non-null  float64
#  4   Leading_Index_for_US                       10542 non-null  float64
#  5   NBER_Recession_Indicator                   10542 non-null  float64
#  6   Producer_Price_Index                       10542 non-null  float64
#  7   5-Year_Breakeven_Inflation                 10542 non-null  float64
#  8   Natural_Rate__of_Unemployment_(est.)       10542 non-null  float64
#  9   Civilian_Labor_Force_Participation         10542 non-null  float64
#  10  BBB_Corporate_Spread                       10542 non-null  float64
#  11  Real_Gross_Domestic_Product                10542 non-null  float64
#  12  Personal_Consumption_Expenditures          10542 non-null  float64
#  13  Industrial_Production_Index                10542 non-null  float64
#  14  Recession_Probabilities                    10542 non-null  float64
#  15  Core_CPI_(ex_Food/Energy)                  10542 non-null  float64
#  16  10-Year_Breakeven_Inflation                10542 non-null  float64
#  17  10-Year_TIPS_Yield                         10542 non-null  float64
#  18  10-Year_Treasury_Yield                     10542 non-null  float64
#  19  Unemployment_Rate                          10542 non-null  float64
#  20  Nonfarm_Payrolls                           10542 non-null  float64
#  21  Job_Openings_(JOLTS)                       10542 non-null  float64
#  22  Effective_Fed_Funds_Rate                   10542 non-null  float64
#  23  2-Year_Treasury_Yield                      10542 non-null  float64
#  24  10Y-2Y_Treasury_Spread                     10542 non-null  float64
#  25  High_Yield_OAS                             10542 non-null  float64
#  26  Equity_Mkt_Vol:_Macro_News_Tracker         10542 non-null  float64
#  27  Equity_Market_Uncertainty_Index            10542 non-null  float64
#  28  U_Mich_Inflation_Expectations              10542 non-null  float64
#  29  Housing_Starts:_Total                      10542 non-null  float64
#  30  New_Private_Housing_Units_Authorized       10542 non-null  float64
#  31  30-Year_Fixed_Mortgage_Rate                10542 non-null  float64
#  32  M2_Money_Stock                             10542 non-null  float64
#  33  ON_RRP_(Reverse_Repo)_Balance              10542 non-null  float64
#  34  Monetary_Base                              10542 non-null  float64
#  35  Commercial_&_Industrial_Loans              10542 non-null  float64
#  36  U_Mich_Consumer_Sentiment                  10542 non-null  float64
#  37  Chicago_Fed_National_Activity_Index        10542 non-null  float64
#  38  CBOE_Volatility_Index (VIX)                10542 non-null  float64
#  39  Chicago_Fed_National_Financial_Conditions  10542 non-null  float64
#  40  Equity_Vol_Tracker:_Broad Macro            10542 non-null  float64
#  41  10Y-3M_Treasury_Spread                     10542 non-null  float64
#  42  Moodys_BAA_Corporate_Bond_Yield            10542 non-null  float64
#  43  Capacity_Utilization:_Manufacturing        10542 non-null  float64
#  44  1-Month_Treasury_Bill                      10542 non-null  float64
#  45  WTI_Crude_Oil_Price                        10542 non-null  float64
#  46  Ticker                                     10542 non-null  object
#  47  Open                                       10542 non-null  float64
#  48  High                                       10542 non-null  float64
#  49  Low                                        10542 non-null  float64
#  50  Close                                      10542 non-null  float64
#  51  Volume                                     10542 non-null  int64
#  52  Dividends                                  10542 non-null  float64
#  53  Stock Splits                               10542 non-null  float64
#  54  Capital Gains                              9036 non-null   float64
#  55  Price_Movement                             10542 non-null  float64
#  56  Price_Movement_Pct                         10542 non-null  float64
#  57  Year                                       10542 non-null  int64
#  58  Month                                      10542 non-null  int64
#  59  Day                                        10542 non-null  int64
#  60  Day_of_Year                                10542 non-null  int64
#  61  Day_of_Week                                10542 non-null  int64
#  62  quarter                                    10542 non-null  int64
#  63  Close_lag1                                 10542 non-null  float64
#  64  Close_lag3                                 10542 non-null  float64
#  65  Close_lag5                                 10542 non-null  float64
#  66  Close_lag7                                 10542 non-null  float64
#  67  Close_lag14                                10542 non-null  float64
#  68  Close_lag21                                10542 non-null  float64
#  69  Close_lag28                                10542 non-null  float64
#  70  Close_lag365                               10542 non-null  float64
#  71  Month_Sin                                  10542 non-null  float64
#  72  Month_Cos                                  10542 non-null  float64
#  73  Dayofweek_Sin                              10542 non-null  float64
#  74  Dayofweek_Cos                              10542 non-null  float64
#  75  Price_Movement_Category                    10542 non-null  object
#  76  Price_Movement_Code                        10542 non-null  int64
#  77  Ticker_Code                                10542 non-null  int64
# dtypes: float64(67), int64(9), object(2)
# memory usage: 6.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10549 entries, 2020-01-02 to 2025-12-30
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker                   10549 non-null  object
#  1   Open                     10549 non-null  float64
#  2   High                     10549 non-null  float64
#  3   Low                      10549 non-null  float64
#  4   Close                    10549 non-null  float64
#  5   Volume                   10549 non-null  int64
#  6   Dividends                10549 non-null  float64
#  7   Stock Splits             10549 non-null  float64
#  8   Capital Gains            9042 non-null   float64
#  9   Price_Movement           10549 non-null  float64
#  10  Price_Movement_Pct       10549 non-null  float64
#  11  Year                     10549 non-null  int64
#  12  Month                    10549 non-null  int64
#  13  Day                      10549 non-null  int64
#  14  Day_of_Year              10549 non-null  int64
#  15  Day_of_Week              10549 non-null  int64
#  16  quarter                  10549 non-null  int64
#  17  Close_lag1               10549 non-null  float64
#  18  Close_lag3               10549 non-null  float64
#  19  Close_lag5               10549 non-null  float64
#  20  Close_lag7               10549 non-null  float64
#  21  Close_lag14              10549 non-null  float64
#  22  Close_lag21              10549 non-null  float64
#  23  Close_lag28              10549 non-null  float64
#  24  Close_lag365             10549 non-null  float64
#  25  Month_Sin                10549 non-null  float64
#  26  Month_Cos                10549 non-null  float64
#  27  Dayofweek_Sin            10549 non-null  float64
#  28  Dayofweek_Cos            10549 non-null  float64
#  29  Price_Movement_Category  10549 non-null  object
#  30  Price_Movement_Code      10549 non-null  int64
#  31  Ticker_Code              10549 non-null  int64
# dtypes: float64(21), int64(9), object(2)
# memory usage: 2.7+ MB
# (None, None)

# %%
ml.shape, ml1.shape
# Out:
# ((10542, 78), (10549, 32))

# %%
drop_column_list = ['Ticker', 'Price_Movement_Category', 'Price_Movement', 'Price_Movement_Pct', 'Price_Movement_Code']

# %%
X_class = ml.drop(drop_column_list, axis=1) 
y_class = ml['Price_Movement_Code']

X_class1 = ml1.drop(drop_column_list, axis=1) 
y_class1 = ml1['Price_Movement_Code']

# %%
# Split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_class, y_class, test_size=0.2, random_state=42
)

X_train1, X_test1, y_train1, y_test1 = train_test_split(
    X_class1, y_class1, test_size=0.2, random_state=42
)

# %%
# Train baseline Random Forest
rf_baseline = RandomForestClassifier(random_state=42)
rf_baseline.fit(X_train, y_train)
rf_baseline1 = RandomForestClassifier(random_state=42)
rf_baseline1.fit(X_train1, y_train1)

# Predictions
y_pred = rf_baseline.predict(X_test)
y_pred1 = rf_baseline1.predict(X_test1)
# Performance
accuracy = accuracy_score(y_test, y_pred)
accuracy1 = accuracy_score(y_test1, y_pred1)

# %%
accuracy * 100, accuracy1 * 100
# Out:
# (87.81412991939308, 65.63981042654028)

# %%
# Detailed metrics
print('Results for model with macroeconomic features:')
print()
print(classification_report(y_test, y_pred, target_names=['High', 'Same', 'Low']))
print()
print('Results for model without macroeconomic features (for comparison):')
print()
print(classification_report(y_test1, y_pred1, target_names=['High', 'Same', 'Low']))
# Out:
# Results for model with macroeconomic features:
#
#               precision    recall  f1-score   support
#
#         High       0.87      0.91      0.89      1128
#         Same       0.00      0.00      0.00        10
#          Low       0.88      0.85      0.87       971
#
#     accuracy                           0.88      2109
#    macro avg       0.59      0.59      0.59      2109
# weighted avg       0.87      0.88      0.88      2109
#
#
# Results for model without macroeconomic features (for comparison):
#
#               precision    recall  f1-score   support
#
#         High       0.65      0.73      0.69      1095
#         Same       0.00      0.00      0.00         6
#          Low       0.66      0.58      0.62      1009
#
#     accuracy                           0.66      2110
#    macro avg       0.44      0.44      0.44      2110
# weighted avg       0.66      0.66      0.65      2110

# %%
# Assume y_test1, y_pred1 for baseline; y_test2, y_pred2 for model 2
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Baseline
cm1 = confusion_matrix(y_test, y_pred)
disp1 = ConfusionMatrixDisplay(cm1, display_labels=['High', 'Same', 'Low'])
disp1.plot(ax=ax1, cmap='Blues', values_format='.0f')
ax1.set_title('ETF Trade Data Merged with Economic Data Model')

# Model 2
cm2 = confusion_matrix(y_test1, y_pred1)
disp2 = ConfusionMatrixDisplay(cm2, display_labels=['High', 'Same', 'Low'])
disp2.plot(ax=ax2, cmap='Reds',values_format='.0f')
ax2.set_title('Just ETF Trade Data Model')

plt.suptitle('ETF Price Movement Prediction: Confusion Matrices', fontsize=16)
plt.tight_layout()
plt.show()

# %%
rf_baseline.feature_importances_, rf_baseline1.feature_importances_
# Out:
# (array([1.48516689e-03, 2.76463480e-03, 4.27484518e-03, 3.11058532e-03,
#         4.19073695e-05, 1.97672498e-05, 4.41073320e-03, 2.98758616e-02,
#         1.72129065e-03, 2.97965897e-03, 2.37164585e-02, 1.97591021e-03,
#         2.74336130e-03, 4.84063022e-03, 4.32627236e-03, 3.18654327e-03,
#         2.92080480e-02, 2.85776134e-02, 2.92197817e-02, 2.65651071e-03,
#         3.23635081e-03, 4.96071949e-03, 2.37932889e-03, 2.58170307e-02,
#         2.85565572e-02, 3.19097646e-02, 5.38034181e-03, 4.31770118e-02,
#         4.14544203e-03, 4.29050980e-03, 4.07820031e-03, 1.74084301e-02,
#         4.89495805e-03, 3.40831869e-02, 4.59889437e-03, 4.08026310e-03,
#         4.34102517e-03, 5.08689716e-03, 5.52739699e-02, 1.80015838e-02,
#         5.51465384e-03, 2.91691757e-02, 2.71909832e-02, 3.68326106e-03,
#         2.31304797e-02, 3.59202453e-02, 1.90489916e-02, 1.77137015e-02,
#         1.84390610e-02, 2.10326615e-02, 2.43466847e-02, 6.86970286e-04,
#         0.00000000e+00, 0.00000000e+00, 4.84253400e-04, 3.62825699e-03,
#         3.37220579e-02, 2.96316115e-02, 1.88019393e-02, 1.59777891e-03,
#         1.94857426e-02, 1.93466423e-02, 1.90079086e-02, 1.96324116e-02,
#         1.85318249e-02, 1.95489595e-02, 1.85259531e-02, 1.49219974e-02,
#         3.33393245e-03, 2.82496593e-03, 1.78681879e-02, 1.54037616e-02,
#         1.09888977e-02]),
#  array([0.05085468, 0.04689768, 0.04814079, 0.06380009, 0.06927654,
#         0.00255569, 0.        , 0.        , 0.02392082, 0.01980109,
#         0.07478743, 0.08256589, 0.01980495, 0.00742342, 0.05296692,
#         0.05088296, 0.05122536, 0.04985178, 0.04984041, 0.05040354,
#         0.05114241, 0.05057137, 0.01924179, 0.01734133, 0.02161726,
#         0.01489923, 0.01018657]))

# %%
X_class.columns, X_class1.columns
# Out:
# (Index(['GDP', 'CPI_Inflation', 'Average_price_of_eggs',
#         'Average_price_of_electricity', 'Leading_Index_for_US',
#         'NBER_Recession_Indicator', 'Producer_Price_Index',
#         '5-Year_Breakeven_Inflation', 'Natural_Rate__of_Unemployment_(est.)',
#         'Civilian_Labor_Force_Participation', 'BBB_Corporate_Spread',
#         'Real_Gross_Domestic_Product', 'Personal_Consumption_Expenditures',
#         'Industrial_Production_Index', 'Recession_Probabilities',
#         'Core_CPI_(ex_Food/Energy)', '10-Year_Breakeven_Inflation',
#         '10-Year_TIPS_Yield', '10-Year_Treasury_Yield', 'Unemployment_Rate',
#         'Nonfarm_Payrolls', 'Job_Openings_(JOLTS)', 'Effective_Fed_Funds_Rate',
#         '2-Year_Treasury_Yield', '10Y-2Y_Treasury_Spread', 'High_Yield_OAS',
#         'Equity_Mkt_Vol:_Macro_News_Tracker', 'Equity_Market_Uncertainty_Index',
#         'U_Mich_Inflation_Expectations', 'Housing_Starts:_Total',
#         'New_Private_Housing_Units_Authorized', '30-Year_Fixed_Mortgage_Rate',
#         'M2_Money_Stock', 'ON_RRP_(Reverse_Repo)_Balance', 'Monetary_Base',
#         'Commercial_&_Industrial_Loans', 'U_Mich_Consumer_Sentiment',
#         'Chicago_Fed_National_Activity_Index', 'CBOE_Volatility_Index (VIX)',
#         'Chicago_Fed_National_Financial_Conditions',
#         'Equity_Vol_Tracker:_Broad Macro', '10Y-3M_Treasury_Spread',
#         'Moodys_BAA_Corporate_Bond_Yield',
#         'Capacity_Utilization:_Manufacturing', '1-Month_Treasury_Bill',
#         'WTI_Crude_Oil_Price', 'Open', 'High', 'Low', 'Close', 'Volume',
#         'Dividends', 'Stock Splits', 'Capital Gains', 'Year', 'Month', 'Day',
#         'Day_of_Year', 'Day_of_Week', 'quarter', 'Close_lag1', 'Close_lag3',
#         'Close_lag5', 'Close_lag7', 'Close_lag14', 'Close_lag21', 'Close_lag28',
#         'Close_lag365', 'Month_Sin', 'Month_Cos', 'Dayofweek_Sin',
#         'Dayofweek_Cos', 'Ticker_Code'],
#        dtype='object'),
#  Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#         'Capital Gains', 'Year', 'Month', 'Day', 'Day_of_Year', 'Day_of_Week',
#         'quarter', 'Close_lag1', 'Close_lag3', 'Close_lag5', 'Close_lag7',
#         'Close_lag14', 'Close_lag21', 'Close_lag28', 'Close_lag365',
#         'Month_Sin', 'Month_Cos', 'Dayofweek_Sin', 'Dayofweek_Cos',
#         'Ticker_Code'],
#        dtype='object'))

# %%
# Get feature importance
feature_importance = pd.DataFrame({
    'feature': X_class.columns,
    'importance': rf_baseline.feature_importances_,
})

feature_importance1= pd.DataFrame({
    'feature1': X_class1.columns,
    'importance1': rf_baseline1.feature_importances_,
})

feature_importance, feature_importance1
# Out:
# (                         feature  importance
#  0                            GDP    0.001485
#  1                  CPI_Inflation    0.002765
#  2          Average_price_of_eggs    0.004275
#  3   Average_price_of_electricity    0.003111
#  4           Leading_Index_for_US    0.000042
#  ..                           ...         ...
#  68                     Month_Sin    0.003334
#  69                     Month_Cos    0.002825
#  70                 Dayofweek_Sin    0.017868
#  71                 Dayofweek_Cos    0.015404
#  72                   Ticker_Code    0.010989
#
#  [73 rows x 2 columns],
#           feature1  importance1
#  0            Open     0.050855
#  1            High     0.046898
#  2             Low     0.048141
#  3           Close     0.063800
#  4          Volume     0.069277
#  5       Dividends     0.002556
#  6    Stock Splits     0.000000
#  7   Capital Gains     0.000000
#  8            Year     0.023921
#  9           Month     0.019801
#  10            Day     0.074787
#  11    Day_of_Year     0.082566
#  12    Day_of_Week     0.019805
#  13        quarter     0.007423
#  14     Close_lag1     0.052967
#  15     Close_lag3     0.050883
#  16     Close_lag5     0.051225
#  17     Close_lag7     0.049852
#  18    Close_lag14     0.049840
#  19    Close_lag21     0.050404
#  20    Close_lag28     0.051142
#  21   Close_lag365     0.050571
#  22      Month_Sin     0.019242
#  23      Month_Cos     0.017341
#  24  Dayofweek_Sin     0.021617
#  25  Dayofweek_Cos     0.014899
#  26    Ticker_Code     0.010187)

# %%
feature_importance = feature_importance.sort_values('importance', ascending=False)
feature_importance1 = feature_importance1.sort_values('importance1', ascending=False)
feature_importance, feature_importance1
# Out:
# (                            feature  importance
#  38      CBOE_Volatility_Index (VIX)    0.055274
#  27  Equity_Market_Uncertainty_Index    0.043177
#  45              WTI_Crude_Oil_Price    0.035920
#  33    ON_RRP_(Reverse_Repo)_Balance    0.034083
#  56                              Day    0.033722
#  ..                              ...         ...
#  54                             Year    0.000484
#  4              Leading_Index_for_US    0.000042
#  5          NBER_Recession_Indicator    0.000020
#  53                    Capital Gains    0.000000
#  52                     Stock Splits    0.000000
#
#  [73 rows x 2 columns],
#           feature1  importance1
#  11    Day_of_Year     0.082566
#  10            Day     0.074787
#  4          Volume     0.069277
#  3           Close     0.063800
#  14     Close_lag1     0.052967
#  16     Close_lag5     0.051225
#  20    Close_lag28     0.051142
#  15     Close_lag3     0.050883
#  0            Open     0.050855
#  21   Close_lag365     0.050571
#  19    Close_lag21     0.050404
#  17     Close_lag7     0.049852
#  18    Close_lag14     0.049840
#  2             Low     0.048141
#  1            High     0.046898
#  8            Year     0.023921
#  24  Dayofweek_Sin     0.021617
#  12    Day_of_Week     0.019805
#  9           Month     0.019801
#  22      Month_Sin     0.019242
#  23      Month_Cos     0.017341
#  25  Dayofweek_Cos     0.014899
#  26    Ticker_Code     0.010187
#  13        quarter     0.007423
#  5       Dividends     0.002556
#  7   Capital Gains     0.000000
#  6    Stock Splits     0.000000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

top = feature_importance.head(20)
ax1.barh(range(len(top)), top['importance'].values, color='blue')
ax1.set_yticks(range(len(top)))
ax1.set_yticklabels(top['feature'].values)
ax1.set_xlabel('Importance Score')
ax1.set_title('Top 20 Feature Importance - Merged with Economic Data Mode ')
ax1.invert_yaxis()

top1 = feature_importance1.head(20)
ax2.barh(range(len(top1)), top1['importance1'].values, color='red')
ax2.set_yticks(range(len(top1)))
ax2.set_yticklabels(top1['feature1'].values)
ax2.set_xlabel('Importance Score')
ax2.set_title('Top 20 Feature Importance - Without Economic Data Mode')
ax2.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Select top features
top_n = 10
selected_features = feature_importance.head(top_n)['feature'].tolist()

top_n1= 10
selected_features1 = feature_importance1.head(top_n1)['feature1'].tolist()

selected_features, selected_features1
# Out:
# (['CBOE_Volatility_Index (VIX)',
#   'Equity_Market_Uncertainty_Index',
#   'WTI_Crude_Oil_Price',
#   'ON_RRP_(Reverse_Repo)_Balance',
#   'Day',
#   'High_Yield_OAS',
#   '5-Year_Breakeven_Inflation',
#   'Day_of_Year',
#   '10-Year_Treasury_Yield',
#   '10-Year_Breakeven_Inflation'],
#  ['Day_of_Year',
#   'Day',
#   'Volume',
#   'Close',
#   'Close_lag1',
#   'Close_lag5',
#   'Close_lag28',
#   'Close_lag3',
#   'Open',
#   'Close_lag365'])

# %%
# Train model with selected features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

rf_selected = RandomForestClassifier(random_state=42)
rf_selected.fit(X_train_selected, y_train)

y_pred_selected = rf_selected.predict(X_test_selected)
accuracy_selected = accuracy_score(y_test, y_pred_selected)

# %%
accuracy_selected * 100
# Out:
# 88.38311996206734

# %%
(accuracy_selected - accuracy) * 100
# Out:
# 0.5689900426742556

# %%
# Import GridSearchCV
from sklearn.model_selection import GridSearchCV

# Define parameter grid (simple)
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10]
}

# %%
# Grid search with cross-validation
rf_grid = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(
    rf_grid, param_grid, 
    cv=5, 
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train_selected, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15, None],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 500]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}

# %%
grid_search.best_score_
# Out:
# np.float64(0.875370585617038)

# %%
# Test the best model
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test_selected)
accuracy_best = accuracy_score(y_test, y_pred_best)

# %%
accuracy, accuracy_best
# Out:
# (0.8781412991939308, 0.8814604077761973)

# %%
accuracy_selected
# Out:
# 0.8838311996206734

# %%
accuracy_best
# Out:
# 0.8814604077761973

# %%
(accuracy_best - accuracy)*100
# Out:
# 0.33191085822664723

# %%
# Final classification report
print(classification_report(y_test, y_pred_best, target_names=['High', 'Same', 'Low']))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.89      0.90      0.89      1128
#         Same       0.00      0.00      0.00        10
#          Low       0.88      0.87      0.87       971
#
#     accuracy                           0.88      2109
#    macro avg       0.59      0.59      0.59      2109
# weighted avg       0.88      0.88      0.88      2109

# %%
# Final confusion matrix
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Baseline
cm_baseline = confusion_matrix(y_test, y_pred)
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_baseline, 
                                display_labels=['High', 'Same', 'Low'])
disp1.plot(ax=axes[0], cmap='Reds')
axes[0].set_title('Baseline Model')

# Best model
cm_best = confusion_matrix(y_test, y_pred_best)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_best, 
                                display_labels=['High', 'Same', 'Low'])
disp2.plot(ax=axes[1], cmap='Greens')
axes[1].set_title('Tuned Model (Best)')

plt.suptitle('Model Comparison: Confusion Matrices', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Feature importance from best model
final_importance = pd.DataFrame({
    'feature': selected_features,
    'importance': best_model.feature_importances_
})

final_importance = final_importance.sort_values('importance', ascending=False)
final_importance
# Out:
#                            feature  importance
# 0      CBOE_Volatility_Index (VIX)    0.141002
# 1  Equity_Market_Uncertainty_Index    0.117069
# 2              WTI_Crude_Oil_Price    0.107229
# 3    ON_RRP_(Reverse_Repo)_Balance    0.098702
# 5                   High_Yield_OAS    0.097972
# 7                      Day_of_Year    0.096253
# 8           10-Year_Treasury_Yield    0.092020
# 6       5-Year_Breakeven_Inflation    0.084418
# 4                              Day    0.083951
# 9      10-Year_Breakeven_Inflation    0.081383

# %%
# Visualise feature importance
plt.figure(figsize=(10, 8))
top_features = final_importance.head(10)
plt.barh(range(len(top_features)), top_features['importance'].values, color = 'green')
plt.yticks(range(len(top_features)), top_features['feature'].values)
plt.xlabel('Importance Score')
plt.title('Top 20 Feature Importance')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
