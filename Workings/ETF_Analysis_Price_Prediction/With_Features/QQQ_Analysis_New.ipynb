# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# For Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# For Classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Make graphs look nice
plt.style.use('seaborn-v0_8-whitegrid')

# %%
df1 = pd.read_csv("../../../Resources/Featured_Files/YFINANCE/QQQ_1d_features.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507 entries, 0 to 1506
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1507 non-null   object
#  1   Ticker                   1507 non-null   object
#  2   Open                     1507 non-null   float64
#  3   High                     1507 non-null   float64
#  4   Low                      1507 non-null   float64
#  5   Close                    1507 non-null   float64
#  6   Volume                   1507 non-null   int64
#  7   Dividends                1507 non-null   float64
#  8   Stock Splits             1507 non-null   float64
#  9   Capital Gains            1507 non-null   float64
#  10  Price_Movement           1507 non-null   float64
#  11  Price_Movement_Pct       1507 non-null   float64
#  12  Year                     1507 non-null   int64
#  13  Month                    1507 non-null   int64
#  14  Day                      1507 non-null   int64
#  15  Day_of_Year              1507 non-null   int64
#  16  Day_of_Week              1507 non-null   int64
#  17  quarter                  1507 non-null   int64
#  18  Close_lag1               1507 non-null   float64
#  19  Close_lag3               1507 non-null   float64
#  20  Close_lag5               1507 non-null   float64
#  21  Close_lag7               1507 non-null   float64
#  22  Close_lag14              1507 non-null   float64
#  23  Close_lag21              1507 non-null   float64
#  24  Close_lag28              1507 non-null   float64
#  25  Close_lag365             1507 non-null   float64
#  26  Month_Sin                1507 non-null   float64
#  27  Month_Cos                1507 non-null   float64
#  28  Dayofweek_Sin            1507 non-null   float64
#  29  Dayofweek_Cos            1507 non-null   float64
#  30  Price_Movement_Category  1507 non-null   object
#  31  Price_Movement_Code      1507 non-null   int64
# dtypes: float64(21), int64(8), object(3)
# memory usage: 376.9+ KB

# %%
df1.shape, df1.head()
# Out:
# ((1507, 32),
#           Date Ticker        Open        High         Low       Close  \
#  0  2020-01-02    QQQ  206.881876  208.580170  206.476606  208.580170
#  1  2020-01-03    QQQ  205.820515  207.914421  205.801212  206.669647
#  2  2020-01-06    QQQ  205.048539  208.030183  204.797662  208.001236
#  3  2020-01-07    QQQ  208.078449  208.560916  207.316157  207.972305
#  4  2020-01-08    QQQ  207.943371  210.490798  207.615297  209.535507
#
#       Volume  Dividends  Stock Splits  Capital Gains  ...  Close_lag14  \
#  0  30969400        0.0           0.0            0.0  ...          0.0
#  1  27518900        0.0           0.0            0.0  ...          0.0
#  2  21655300        0.0           0.0            0.0  ...          0.0
#  3  22139300        0.0           0.0            0.0  ...          0.0
#  4  26397300        0.0           0.0            0.0  ...          0.0
#
#     Close_lag21  Close_lag28  Close_lag365  Month_Sin  Month_Cos  \
#  0          0.0          0.0           0.0        0.5   0.866025
#  1          0.0          0.0           0.0        0.5   0.866025
#  2          0.0          0.0           0.0        0.5   0.866025
#  3          0.0          0.0           0.0        0.5   0.866025
#  4          0.0          0.0           0.0        0.5   0.866025
#
#     Dayofweek_Sin  Dayofweek_Cos  Price_Movement_Category  Price_Movement_Code
#  0       0.433884      -0.900969                     high                    0
#  1      -0.433884      -0.900969                     high                    0
#  2       0.000000       1.000000                     high                    0
#  3       0.781831       0.623490                      low                    2
#  4       0.974928      -0.222521                     high                    0
#
#  [5 rows x 32 columns])

# %%
df2 = pd.read_csv(r"../../../Resources/Raw_Files/FRED/fred_macro_data.csv")

# %%
df2.info(), df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       2190 non-null   object
#  1   GDP                                        2190 non-null   float64
#  2   CPI_Inflation                              2190 non-null   float64
#  3   Average_price_of_eggs                      2190 non-null   float64
#  4   Average_price_of_electricity               2190 non-null   float64
#  5   Leading_Index_for_US                       2190 non-null   float64
#  6   NBER_Recession_Indicator                   2190 non-null   float64
#  7   Producer_Price_Index                       2190 non-null   float64
#  8   5-Year_Breakeven_Inflation                 2190 non-null   float64
#  9   Natural_Rate__of_Unemployment_(est.)       2190 non-null   float64
#  10  Civilian_Labor_Force_Participation         2190 non-null   float64
#  11  BBB_Corporate_Spread                       2190 non-null   float64
#  12  Real_Gross_Domestic_Product                2190 non-null   float64
#  13  Personal_Consumption_Expenditures          2190 non-null   float64
#  14  Industrial_Production_Index                2190 non-null   float64
#  15  Recession_Probabilities                    2190 non-null   float64
#  16  Core_CPI_(ex_Food/Energy)                  2190 non-null   float64
#  17  10-Year_Breakeven_Inflation                2190 non-null   float64
#  18  10-Year_TIPS_Yield                         2190 non-null   float64
#  19  10-Year_Treasury_Yield                     2190 non-null   float64
#  20  Unemployment_Rate                          2190 non-null   float64
#  21  Nonfarm_Payrolls                           2190 non-null   float64
#  22  Job_Openings_(JOLTS)                       2190 non-null   float64
#  23  Effective_Fed_Funds_Rate                   2190 non-null   float64
#  24  2-Year_Treasury_Yield                      2190 non-null   float64
#  25  10Y-2Y_Treasury_Spread                     2190 non-null   float64
#  26  High_Yield_OAS                             2190 non-null   float64
#  27  Equity_Mkt_Vol:_Macro_News_Tracker         2190 non-null   float64
#  28  Equity_Market_Uncertainty_Index            2190 non-null   float64
#  29  U_Mich_Inflation_Expectations              2190 non-null   float64
#  30  Housing_Starts:_Total                      2190 non-null   float64
#  31  New_Private_Housing_Units_Authorized       2190 non-null   float64
#  32  30-Year_Fixed_Mortgage_Rate                2190 non-null   float64
#  33  M2_Money_Stock                             2190 non-null   float64
#  34  ON_RRP_(Reverse_Repo)_Balance              2190 non-null   float64
#  35  Monetary_Base                              2190 non-null   float64
#  36  Commercial_&_Industrial_Loans              2190 non-null   float64
#  37  U_Mich_Consumer_Sentiment                  2190 non-null   float64
#  38  Chicago_Fed_National_Activity_Index        2190 non-null   float64
#  39  CBOE_Volatility_Index (VIX)                2190 non-null   float64
#  40  Chicago_Fed_National_Financial_Conditions  2190 non-null   float64
#  41  Equity_Vol_Tracker:_Broad Macro            2190 non-null   float64
#  42  10Y-3M_Treasury_Spread                     2190 non-null   float64
#  43  Moodys_BAA_Corporate_Bond_Yield            2190 non-null   float64
#  44  Capacity_Utilization:_Manufacturing        2190 non-null   float64
#  45  1-Month_Treasury_Bill                      2190 non-null   float64
#  46  WTI_Crude_Oil_Price                        2190 non-null   float64
# dtypes: float64(46), object(1)
# memory usage: 804.3+ KB
# (None,
#           Date        GDP  CPI_Inflation  Average_price_of_eggs  \
#  0  2020-01-03  21751.238        259.127                  1.461
#  1  2020-01-04  21751.238        259.127                  1.461
#  2  2020-01-05  21751.238        259.127                  1.461
#  3  2020-01-06  21751.238        259.127                  1.461
#  4  2020-01-07  21751.238        259.127                  1.461
#
#     Average_price_of_electricity  Leading_Index_for_US  \
#  0                         0.134                  1.57
#  1                         0.134                  1.57
#  2                         0.134                  1.57
#  3                         0.134                  1.57
#  4                         0.134                  1.57
#
#     NBER_Recession_Indicator  Producer_Price_Index  5-Year_Breakeven_Inflation  \
#  0                       0.0                 199.3                        1.85
#  1                       0.0                 199.3                        1.85
#  2                       0.0                 199.3                        1.85
#  3                       0.0                 199.3                        1.81
#  4                       0.0                 199.3                        1.81
#
#     Natural_Rate__of_Unemployment_(est.)  ...  U_Mich_Consumer_Sentiment  \
#  0                              4.403836  ...                       99.8
#  1                              4.403836  ...                       99.8
#  2                              4.403836  ...                       99.8
#  3                              4.403836  ...                       99.8
#  4                              4.403836  ...                       99.8
#
#     Chicago_Fed_National_Activity_Index  CBOE_Volatility_Index (VIX)  \
#  0                                -0.25                        14.02
#  1                                -0.25                        14.02
#  2                                -0.25                        14.02
#  3                                -0.25                        13.85
#  4                                -0.25                        13.79
#
#     Chicago_Fed_National_Financial_Conditions  Equity_Vol_Tracker:_Broad Macro  \
#  0                                   -0.56878                          5.66965
#  1                                   -0.56878                          5.66965
#  2                                   -0.56878                          5.66965
#  3                                   -0.56878                          5.66965
#  4                                   -0.56878                          5.66965
#
#     10Y-3M_Treasury_Spread  Moodys_BAA_Corporate_Bond_Yield  \
#  0                    0.28                             1.99
#  1                    0.28                             1.99
#  2                    0.28                             1.99
#  3                    0.25                             2.02
#  4                    0.29                             2.03
#
#     Capacity_Utilization:_Manufacturing  1-Month_Treasury_Bill  \
#  0                                208.0                   1.52
#  1                                208.0                   1.52
#  2                                208.0                   1.52
#  3                                208.0                   1.54
#  4                                208.0                   1.52
#
#     WTI_Crude_Oil_Price
#  0                63.00
#  1                63.00
#  2                63.00
#  3                63.27
#  4                62.70
#
#  [5 rows x 47 columns])

# %%
merged = df2.merge(df1, on="Date", how="inner")

# %%
merged.shape, merged.head()
# Out:
# ((1506, 78),
#           Date        GDP  CPI_Inflation  Average_price_of_eggs  \
#  0  2020-01-03  21751.238        259.127                  1.461
#  1  2020-01-06  21751.238        259.127                  1.461
#  2  2020-01-07  21751.238        259.127                  1.461
#  3  2020-01-08  21751.238        259.127                  1.461
#  4  2020-01-09  21751.238        259.127                  1.461
#
#     Average_price_of_electricity  Leading_Index_for_US  \
#  0                         0.134                  1.57
#  1                         0.134                  1.57
#  2                         0.134                  1.57
#  3                         0.134                  1.57
#  4                         0.134                  1.57
#
#     NBER_Recession_Indicator  Producer_Price_Index  5-Year_Breakeven_Inflation  \
#  0                       0.0                 199.3                        1.85
#  1                       0.0                 199.3                        1.81
#  2                       0.0                 199.3                        1.81
#  3                       0.0                 199.3                        1.82
#  4                       0.0                 199.3                        1.81
#
#     Natural_Rate__of_Unemployment_(est.)  ...  Close_lag14  Close_lag21  \
#  0                              4.403836  ...          0.0          0.0
#  1                              4.403836  ...          0.0          0.0
#  2                              4.403836  ...          0.0          0.0
#  3                              4.403836  ...          0.0          0.0
#  4                              4.403836  ...          0.0          0.0
#
#     Close_lag28  Close_lag365  Month_Sin  Month_Cos  Dayofweek_Sin  \
#  0          0.0           0.0        0.5   0.866025      -0.433884
#  1          0.0           0.0        0.5   0.866025       0.000000
#  2          0.0           0.0        0.5   0.866025       0.781831
#  3          0.0           0.0        0.5   0.866025       0.974928
#  4          0.0           0.0        0.5   0.866025       0.433884
#
#     Dayofweek_Cos  Price_Movement_Category  Price_Movement_Code
#  0      -0.900969                     high                    0
#  1       1.000000                     high                    0
#  2       0.623490                      low                    2
#  3      -0.222521                     high                    0
#  4      -0.900969                     high                    0
#
#  [5 rows x 78 columns])

# %%
def movement_category(movement):
    if movement == "high":
        return 1
    elif movement == "same": 
        return 0
    else:
        return -1

# %%
merged['Price_Movement_Category'] = merged['Price_Movement_Category'].apply(movement_category)

# %%
merged.shape, merged.head()
# Out:
# ((1506, 78),
#           Date        GDP  CPI_Inflation  Average_price_of_eggs  \
#  0  2020-01-03  21751.238        259.127                  1.461
#  1  2020-01-06  21751.238        259.127                  1.461
#  2  2020-01-07  21751.238        259.127                  1.461
#  3  2020-01-08  21751.238        259.127                  1.461
#  4  2020-01-09  21751.238        259.127                  1.461
#
#     Average_price_of_electricity  Leading_Index_for_US  \
#  0                         0.134                  1.57
#  1                         0.134                  1.57
#  2                         0.134                  1.57
#  3                         0.134                  1.57
#  4                         0.134                  1.57
#
#     NBER_Recession_Indicator  Producer_Price_Index  5-Year_Breakeven_Inflation  \
#  0                       0.0                 199.3                        1.85
#  1                       0.0                 199.3                        1.81
#  2                       0.0                 199.3                        1.81
#  3                       0.0                 199.3                        1.82
#  4                       0.0                 199.3                        1.81
#
#     Natural_Rate__of_Unemployment_(est.)  ...  Close_lag14  Close_lag21  \
#  0                              4.403836  ...          0.0          0.0
#  1                              4.403836  ...          0.0          0.0
#  2                              4.403836  ...          0.0          0.0
#  3                              4.403836  ...          0.0          0.0
#  4                              4.403836  ...          0.0          0.0
#
#     Close_lag28  Close_lag365  Month_Sin  Month_Cos  Dayofweek_Sin  \
#  0          0.0           0.0        0.5   0.866025      -0.433884
#  1          0.0           0.0        0.5   0.866025       0.000000
#  2          0.0           0.0        0.5   0.866025       0.781831
#  3          0.0           0.0        0.5   0.866025       0.974928
#  4          0.0           0.0        0.5   0.866025       0.433884
#
#     Dayofweek_Cos  Price_Movement_Category  Price_Movement_Code
#  0      -0.900969                        1                    0
#  1       1.000000                        1                    0
#  2       0.623490                       -1                    2
#  3      -0.222521                        1                    0
#  4      -0.900969                        1                    0
#
#  [5 rows x 78 columns])

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 78 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       1506 non-null   object
#  1   GDP                                        1506 non-null   float64
#  2   CPI_Inflation                              1506 non-null   float64
#  3   Average_price_of_eggs                      1506 non-null   float64
#  4   Average_price_of_electricity               1506 non-null   float64
#  5   Leading_Index_for_US                       1506 non-null   float64
#  6   NBER_Recession_Indicator                   1506 non-null   float64
#  7   Producer_Price_Index                       1506 non-null   float64
#  8   5-Year_Breakeven_Inflation                 1506 non-null   float64
#  9   Natural_Rate__of_Unemployment_(est.)       1506 non-null   float64
#  10  Civilian_Labor_Force_Participation         1506 non-null   float64
#  11  BBB_Corporate_Spread                       1506 non-null   float64
#  12  Real_Gross_Domestic_Product                1506 non-null   float64
#  13  Personal_Consumption_Expenditures          1506 non-null   float64
#  14  Industrial_Production_Index                1506 non-null   float64
#  15  Recession_Probabilities                    1506 non-null   float64
#  16  Core_CPI_(ex_Food/Energy)                  1506 non-null   float64
#  17  10-Year_Breakeven_Inflation                1506 non-null   float64
#  18  10-Year_TIPS_Yield                         1506 non-null   float64
#  19  10-Year_Treasury_Yield                     1506 non-null   float64
#  20  Unemployment_Rate                          1506 non-null   float64
#  21  Nonfarm_Payrolls                           1506 non-null   float64
#  22  Job_Openings_(JOLTS)                       1506 non-null   float64
#  23  Effective_Fed_Funds_Rate                   1506 non-null   float64
#  24  2-Year_Treasury_Yield                      1506 non-null   float64
#  25  10Y-2Y_Treasury_Spread                     1506 non-null   float64
#  26  High_Yield_OAS                             1506 non-null   float64
#  27  Equity_Mkt_Vol:_Macro_News_Tracker         1506 non-null   float64
#  28  Equity_Market_Uncertainty_Index            1506 non-null   float64
#  29  U_Mich_Inflation_Expectations              1506 non-null   float64
#  30  Housing_Starts:_Total                      1506 non-null   float64
#  31  New_Private_Housing_Units_Authorized       1506 non-null   float64
#  32  30-Year_Fixed_Mortgage_Rate                1506 non-null   float64
#  33  M2_Money_Stock                             1506 non-null   float64
#  34  ON_RRP_(Reverse_Repo)_Balance              1506 non-null   float64
#  35  Monetary_Base                              1506 non-null   float64
#  36  Commercial_&_Industrial_Loans              1506 non-null   float64
#  37  U_Mich_Consumer_Sentiment                  1506 non-null   float64
#  38  Chicago_Fed_National_Activity_Index        1506 non-null   float64
#  39  CBOE_Volatility_Index (VIX)                1506 non-null   float64
#  40  Chicago_Fed_National_Financial_Conditions  1506 non-null   float64
#  41  Equity_Vol_Tracker:_Broad Macro            1506 non-null   float64
#  42  10Y-3M_Treasury_Spread                     1506 non-null   float64
#  43  Moodys_BAA_Corporate_Bond_Yield            1506 non-null   float64
#  44  Capacity_Utilization:_Manufacturing        1506 non-null   float64
#  45  1-Month_Treasury_Bill                      1506 non-null   float64
#  46  WTI_Crude_Oil_Price                        1506 non-null   float64
#  47  Ticker                                     1506 non-null   object
#  48  Open                                       1506 non-null   float64
#  49  High                                       1506 non-null   float64
#  50  Low                                        1506 non-null   float64
#  51  Close                                      1506 non-null   float64
#  52  Volume                                     1506 non-null   int64
#  53  Dividends                                  1506 non-null   float64
#  54  Stock Splits                               1506 non-null   float64
#  55  Capital Gains                              1506 non-null   float64
#  56  Price_Movement                             1506 non-null   float64
#  57  Price_Movement_Pct                         1506 non-null   float64
#  58  Year                                       1506 non-null   int64
#  59  Month                                      1506 non-null   int64
#  60  Day                                        1506 non-null   int64
#  61  Day_of_Year                                1506 non-null   int64
#  62  Day_of_Week                                1506 non-null   int64
#  63  quarter                                    1506 non-null   int64
#  64  Close_lag1                                 1506 non-null   float64
#  65  Close_lag3                                 1506 non-null   float64
#  66  Close_lag5                                 1506 non-null   float64
#  67  Close_lag7                                 1506 non-null   float64
#  68  Close_lag14                                1506 non-null   float64
#  69  Close_lag21                                1506 non-null   float64
#  70  Close_lag28                                1506 non-null   float64
#  71  Close_lag365                               1506 non-null   float64
#  72  Month_Sin                                  1506 non-null   float64
#  73  Month_Cos                                  1506 non-null   float64
#  74  Dayofweek_Sin                              1506 non-null   float64
#  75  Dayofweek_Cos                              1506 non-null   float64
#  76  Price_Movement_Category                    1506 non-null   int64
#  77  Price_Movement_Code                        1506 non-null   int64
# dtypes: float64(67), int64(9), object(2)
# memory usage: 917.8+ KB

# %%
drop_list = ['Date','Ticker','Open', 'High', 'Low']

# %%
merged = merged.drop(drop_list,axis=1)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506 entries, 0 to 1505
# Data columns (total 73 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GDP                                        1506 non-null   float64
#  1   CPI_Inflation                              1506 non-null   float64
#  2   Average_price_of_eggs                      1506 non-null   float64
#  3   Average_price_of_electricity               1506 non-null   float64
#  4   Leading_Index_for_US                       1506 non-null   float64
#  5   NBER_Recession_Indicator                   1506 non-null   float64
#  6   Producer_Price_Index                       1506 non-null   float64
#  7   5-Year_Breakeven_Inflation                 1506 non-null   float64
#  8   Natural_Rate__of_Unemployment_(est.)       1506 non-null   float64
#  9   Civilian_Labor_Force_Participation         1506 non-null   float64
#  10  BBB_Corporate_Spread                       1506 non-null   float64
#  11  Real_Gross_Domestic_Product                1506 non-null   float64
#  12  Personal_Consumption_Expenditures          1506 non-null   float64
#  13  Industrial_Production_Index                1506 non-null   float64
#  14  Recession_Probabilities                    1506 non-null   float64
#  15  Core_CPI_(ex_Food/Energy)                  1506 non-null   float64
#  16  10-Year_Breakeven_Inflation                1506 non-null   float64
#  17  10-Year_TIPS_Yield                         1506 non-null   float64
#  18  10-Year_Treasury_Yield                     1506 non-null   float64
#  19  Unemployment_Rate                          1506 non-null   float64
#  20  Nonfarm_Payrolls                           1506 non-null   float64
#  21  Job_Openings_(JOLTS)                       1506 non-null   float64
#  22  Effective_Fed_Funds_Rate                   1506 non-null   float64
#  23  2-Year_Treasury_Yield                      1506 non-null   float64
#  24  10Y-2Y_Treasury_Spread                     1506 non-null   float64
#  25  High_Yield_OAS                             1506 non-null   float64
#  26  Equity_Mkt_Vol:_Macro_News_Tracker         1506 non-null   float64
#  27  Equity_Market_Uncertainty_Index            1506 non-null   float64
#  28  U_Mich_Inflation_Expectations              1506 non-null   float64
#  29  Housing_Starts:_Total                      1506 non-null   float64
#  30  New_Private_Housing_Units_Authorized       1506 non-null   float64
#  31  30-Year_Fixed_Mortgage_Rate                1506 non-null   float64
#  32  M2_Money_Stock                             1506 non-null   float64
#  33  ON_RRP_(Reverse_Repo)_Balance              1506 non-null   float64
#  34  Monetary_Base                              1506 non-null   float64
#  35  Commercial_&_Industrial_Loans              1506 non-null   float64
#  36  U_Mich_Consumer_Sentiment                  1506 non-null   float64
#  37  Chicago_Fed_National_Activity_Index        1506 non-null   float64
#  38  CBOE_Volatility_Index (VIX)                1506 non-null   float64
#  39  Chicago_Fed_National_Financial_Conditions  1506 non-null   float64
#  40  Equity_Vol_Tracker:_Broad Macro            1506 non-null   float64
#  41  10Y-3M_Treasury_Spread                     1506 non-null   float64
#  42  Moodys_BAA_Corporate_Bond_Yield            1506 non-null   float64
#  43  Capacity_Utilization:_Manufacturing        1506 non-null   float64
#  44  1-Month_Treasury_Bill                      1506 non-null   float64
#  45  WTI_Crude_Oil_Price                        1506 non-null   float64
#  46  Close                                      1506 non-null   float64
#  47  Volume                                     1506 non-null   int64
#  48  Dividends                                  1506 non-null   float64
#  49  Stock Splits                               1506 non-null   float64
#  50  Capital Gains                              1506 non-null   float64
#  51  Price_Movement                             1506 non-null   float64
#  52  Price_Movement_Pct                         1506 non-null   float64
#  53  Year                                       1506 non-null   int64
#  54  Month                                      1506 non-null   int64
#  55  Day                                        1506 non-null   int64
#  56  Day_of_Year                                1506 non-null   int64
#  57  Day_of_Week                                1506 non-null   int64
#  58  quarter                                    1506 non-null   int64
#  59  Close_lag1                                 1506 non-null   float64
#  60  Close_lag3                                 1506 non-null   float64
#  61  Close_lag5                                 1506 non-null   float64
#  62  Close_lag7                                 1506 non-null   float64
#  63  Close_lag14                                1506 non-null   float64
#  64  Close_lag21                                1506 non-null   float64
#  65  Close_lag28                                1506 non-null   float64
#  66  Close_lag365                               1506 non-null   float64
#  67  Month_Sin                                  1506 non-null   float64
#  68  Month_Cos                                  1506 non-null   float64
#  69  Dayofweek_Sin                              1506 non-null   float64
#  70  Dayofweek_Cos                              1506 non-null   float64
#  71  Price_Movement_Category                    1506 non-null   int64
#  72  Price_Movement_Code                        1506 non-null   int64
# dtypes: float64(64), int64(9)
# memory usage: 859.0 KB

# %%
merged = merged.fillna(0)

# %%
df3 = merged.copy()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(
                                    df3.drop(['Close'],axis=1),
                                    df3['Close'],
                                    test_size=0.2,
                                    random_state=101
                                    )

print("* Train set:", X_train.shape, y_train.shape, "\n* Test set:", X_test.shape, y_test.shape)
# Out:
# * Train set: (1204, 72) (1204,)
# * Test set: (302, 72) (302,)

# %%
from sklearn.pipeline import Pipeline

### Feat Scaling
from sklearn.preprocessing import StandardScaler

### Feat Selection
from sklearn.feature_selection import SelectFromModel

### ML algorithms 
#from sklearn.ensemble import AdaBoostRegressor
#from sklearn.linear_model import LinearRegression
#from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
#from sklearn.tree import DecisionTreeRegressor

def pipeline_adaboost_reg():
  pipeline = Pipeline([
      ( "feat_scaling",StandardScaler() ),
      ( "feat_selection",SelectFromModel(RandomForestRegressor(random_state=101)) ),
      ( "model", RandomForestRegressor(random_state=101)),

    ])

  return pipeline

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html  # documentation is here
param_grid = {"model__n_estimators":[10,20],
              }

param_grid
# Out:
# {'model__n_estimators': [10, 20]}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=pipeline_adaboost_reg(),
                    param_grid=param_grid,
                    cv=2,
                    n_jobs=-2,
                    verbose=3,  # for learning, we set 3 to print the score from every cross-validation
                    scoring='r2')


grid.fit(X_train,y_train)
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('feat_scaling', StandardScaler()),
#                                        ('feat_selection',
#                                         SelectFromModel(estimator=RandomForestRegressor(random_state=101))),
#                                        ('model',
#                                         RandomForestRegressor(random_state=101))]),
#              n_jobs=-2, param_grid={'model__n_estimators': [10, 20]},
#              scoring='r2', verbose=3)

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([1.69310713, 1.76910412]),
#  'std_fit_time': array([0.00797915, 0.03431618]),
#  'mean_score_time': array([0.03001308, 0.02598095]),
#  'std_score_time': array([0.00106215, 0.00033236]),
#  'param_model__n_estimators': masked_array(data=[10, 20],
#               mask=[False, False],
#         fill_value=999999),
#  'params': [{'model__n_estimators': 10}, {'model__n_estimators': 20}],
#  'split0_test_score': array([0.99679717, 0.99687241]),
#  'split1_test_score': array([0.99667085, 0.99682269]),
#  'mean_test_score': array([0.99673401, 0.99684755]),
#  'std_test_score': array([6.31613517e-05, 2.48611372e-05]),
#  'rank_test_score': array([2, 1], dtype=int32)}

# %%
(pd.DataFrame(grid.cv_results_)
.sort_values(by='mean_test_score',ascending=False)
.filter(['params','mean_test_score'])
.values
 )
# Out:
# array([[{'model__n_estimators': 20}, 0.9968475536931426],
#        [{'model__n_estimators': 10}, 0.9967340109783333]], dtype=object)

# %%
grid.best_params_
# Out:
# {'model__n_estimators': 20}

# %%
pipeline = grid.best_estimator_
pipeline
# Out:
# Pipeline(steps=[('feat_scaling', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=RandomForestRegressor(random_state=101))),
#                 ('model',
#                  RandomForestRegressor(n_estimators=20, random_state=101))])

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error 
import numpy as np

def regression_performance(X_train, y_train, X_test, y_test,pipeline):
	print("Model Evaluation \n")
	print("* Train Set")
	regression_evaluation(X_train,y_train,pipeline)
	print("* Test Set")
	regression_evaluation(X_test,y_test,pipeline)



def regression_evaluation(X,y,pipeline):
  prediction = pipeline.predict(X)
  print('R2 Score:', round(r2_score(y, prediction), 3))
  print('Mean Absolute Error:', round(mean_absolute_error(y, prediction), 3))
  print('Mean Squared Error:', round(mean_squared_error(y, prediction), 3))
  print('Root Mean Squared Error:',
          round(np.sqrt(mean_squared_error(y, prediction)), 3))
  print("\n")

  

def regression_evaluation_plots(X_train, y_train, X_test, y_test,pipeline, alpha_scatter=0.5):
  pred_train = pipeline.predict(X_train)
  pred_test = pipeline.predict(X_test)


  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
  sns.scatterplot(x=y_train , y=pred_train, alpha=alpha_scatter, ax=axes[0])
  sns.lineplot(x=y_train , y=y_train, color='red', ax=axes[0])
  axes[0].set_xlabel("Actual")
  axes[0].set_ylabel("Predictions")
  axes[0].set_title("Train Set")

  sns.scatterplot(x=y_test , y=pred_test, alpha=alpha_scatter, ax=axes[1])
  sns.lineplot(x=y_test , y=y_test, color='red', ax=axes[1])
  axes[1].set_xlabel("Actual")
  axes[1].set_ylabel("Predictions")
  axes[1].set_title("Test Set")
  plt.show()

# %%
regression_performance(X_train, y_train, X_test, y_test,pipeline)
regression_evaluation_plots(X_train, y_train, X_test, y_test, 
                            pipeline, alpha_scatter=0.5)
# Out:
# Model Evaluation
#
# * Train Set
# R2 Score: 1.0
# Mean Absolute Error: 1.659
# Mean Squared Error: 5.124
# Root Mean Squared Error: 2.264
#
#
# * Test Set
# R2 Score: 0.997
# Mean Absolute Error: 4.443
# Mean Squared Error: 42.076
# Root Mean Squared Error: 6.487

# %%
print(f"Training on {len(X_train)} QQQ ETFs")
print(f"Testing on {len(X_test)} QQQ ETFs")
# Out:
# Training on 1204 QQQ ETFs
# Testing on 302 QQQ ETFs

# %%
# Train the regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([448.59430642, 420.532723  , 365.38303444, 307.87002873,
#        206.22238884, 366.05315616, 258.76745637, 486.87704214,
#        325.27567131, 293.3623427 , 575.70474426, 282.70549895,
#        345.711355  , 296.02120629, 385.54197367, 307.39142257,
#        210.62285321, 232.20760093, 542.79388533, 343.29470247,
#        615.90885009, 437.24817371, 593.98357929, 366.43440898,
#        369.12111637, 537.9605932 , 202.40357029, 264.74242296,
#        284.5273628 , 368.03409315, 303.20145256, 337.13575426,
#        280.14700352, 605.33207578, 223.57663545, 456.30364809,
#        217.7217936 , 511.48337171, 326.91758992, 285.52802914,
#        187.85307067, 251.60004864, 476.73175013, 353.57701928,
#        299.3093852 , 321.70816877, 299.28900702, 275.59274984,
#        526.15369426, 357.75909406, 513.03247873, 310.37597899,
#        312.86571314, 273.296849  , 508.39586355, 353.05695198,
#        523.38643689, 304.48228878, 593.70781131, 345.88971856,
#        423.63342248, 211.54715914, 260.39278504, 203.28373509,
#        485.44984314, 425.15517105, 479.0683949 , 377.92250083,
#        309.26572113, 286.59873179, 291.513243  , 571.11330007,
#        415.77874105, 358.67901687, 325.24072941, 515.99859755,
#        371.70058094, 509.67609307, 316.20065853, 437.09241929,
#        368.45678479, 338.76288685, 460.88586702, 348.52720644,
#        291.59776348, 286.89096642, 584.82085007, 280.10714551,
#        439.08386417, 446.83379907, 374.05768941, 420.86721206,
#        490.87965835, 531.21866899, 260.35861047, 453.28915613,
#        254.01836111, 287.21536223, 507.69130844, 352.57279114,
#        318.46139664, 324.88743627, 588.48976414, 307.03246245,
#        213.34154991, 323.99648664, 604.5735967 , 237.42181191,
#        508.14763281, 308.21688864, 309.49121207, 199.27443317,
#        519.18219249, 267.36592211, 349.99719335, 324.64956815,
#        292.54597588, 225.78651414, 356.14051614, 171.60003067,
#        622.80000923, 322.35051439, 210.83139791, 438.23494316,
#        438.83230379, 235.89451964, 332.30607154, 301.60854524,
#        376.38792075, 358.27732735, 357.66859016, 324.59993331,
#        512.89364376, 285.60035747, 252.09792187, 377.1699755 ,
#        271.68375856, 346.2147625 , 277.8824017 , 269.00056309,
#        332.9484589 , 477.14087636, 529.91577551, 252.70856181,
#        191.716179  , 277.19434931, 450.74728584, 317.52784649,
#        596.10030666, 578.10960927, 350.21093242, 355.27790864,
#        377.83281599, 307.85100869, 361.54188004, 488.39606535,
#        414.16487912, 619.59107616, 308.48836514, 436.375451  ,
#        198.00711047, 214.81458138, 600.35015916, 534.65928101,
#        275.40918133, 450.24291284, 272.44244649, 426.7557081 ,
#        308.97713426, 429.65635434, 316.77862205, 282.52670409,
#        277.50597822, 354.65341527, 275.99029858, 437.67395181,
#        533.37249432, 260.91270134, 269.8292259 , 434.51328566,
#        478.33988456, 521.8511697 , 607.73959625, 361.54581627,
#        333.06178662, 369.08517048, 269.89487641, 520.47491589,
#        288.96380059, 320.46626914, 471.424017  , 608.19061107,
#        258.59402818, 469.85611456, 499.3157915 , 383.90788394,
#        421.6902468 , 275.99520343, 233.73143227, 267.22266136,
#        479.82522833, 397.84228851, 267.36524761, 268.13799693,
#        522.65489595, 323.8036762 , 218.23842429, 371.14049623,
#        291.45650364, 518.54888596, 429.92236197, 307.75127043,
#        371.07089658, 569.91559231, 267.6114168 , 364.88568083,
#        272.38223798, 570.42125729, 332.54662214, 515.63300078,
#        336.80738654, 346.76059154, 601.87802237, 206.29362531,
#        473.28221689, 363.51129172, 319.28146738, 254.17583817,
#        331.33848618, 356.71088503, 417.75262227, 352.78813326,
#        349.16484075, 299.40641198, 283.82935777, 474.05816952,
#        258.10636359, 267.67973476, 340.81049948, 347.02091822,
#        299.18475644, 264.64671205, 348.00396371, 327.87183892,
#        263.77594044, 338.26698687, 326.23063561, 371.85075128,
#        360.29284941, 450.86244421, 357.25389352, 255.817787  ,
#        270.46317383, 436.16655086, 269.85283452, 292.13960262,
#        227.1184107 , 391.510275  , 445.96787476, 226.05537861,
#        330.64283317, 510.60053271, 333.13712636, 397.81862479,
#        473.69646302, 166.44933525, 222.26079981, 421.44245087,
#        277.65393896, 205.37471159, 284.25286369, 369.53152494,
#        326.15427184, 356.06315694, 522.62058877, 498.54199882,
#        345.0230109 , 261.53310905, 620.41535267, 307.9089139 ,
#        467.22252126, 227.38517181, 300.52483671, 319.23071535,
#        217.52360093, 300.83776833, 618.56583394, 628.15800914,
#        560.53206156, 258.02878317, 358.28375498, 355.45261826,
#        291.27409587, 374.58164304, 286.22278103, 294.82866226,
#        285.87602558, 451.34750227, 504.66425223, 223.67811485,
#        287.75279074, 175.3324949 ])

# %%
# Simple line plot - Actual vs Predicted
plt.figure(figsize=(12, 6))

# Plot both lines
x_axis = range(len(y_test))
plt.plot(x_axis, y_test.values, 'b--', label='Actual QQQ ETF Prices', linewidth=2)
plt.plot(x_axis, y_pred, 'r--', label='Our Predictions', linewidth=2)

plt.xlabel('ETF Number')
plt.ylabel('Price (USD)')
plt.title('Actual QQQ ETF Prices vs Our Predictions')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("REGRESSION METRICS EXPLAINED:")
print("=" * 50)
print()
print("Mean Absolute Error (MAE)")
print(f"   Your MAE: ${mae:,.0f}")
print("   What it means: On average, our predictions are off by this much")
print("   Think of it as: The typical mistake we make")
print("   Goal: Lower is better!")
print()
print("R² Score (R-squared)")
print(f"   Your R²: {r2:.1%}")
print("   What it means: How much of the price variation we can explain")
print("   Think of it as: Our model's grade out of 100%")
print("   Goal: Higher is better (100% = perfect, 0% = terrible)")
print()
print("Quick Guide:")
print("   R² > 80% = Great!")
print("   R² 70-80% = Good")
print("   R² 60-70% = OK")
print("   R² < 60% = Needs improvement")
# Out:
# REGRESSION METRICS EXPLAINED:
# ==================================================
#
# Mean Absolute Error (MAE)
#    Your MAE: $2
#    What it means: On average, our predictions are off by this much
#    Think of it as: The typical mistake we make
#    Goal: Lower is better!
#
# R² Score (R-squared)
#    Your R²: 99.9%
#    What it means: How much of the price variation we can explain
#    Think of it as: Our model's grade out of 100%
#    Goal: Higher is better (100% = perfect, 0% = terrible)
#
# Quick Guide:
#    R² > 80% = Great!
#    R² 70-80% = Good
#    R² 60-70% = OK
#    R² < 60% = Needs improvement

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor

def pipeline_adaboost_reg():
    pipeline = Pipeline([
        ("feat_scaling", StandardScaler()),
        ("feat_selection", SelectFromModel(RandomForestRegressor(random_state=101))),
        ("model", RandomForestRegressor(random_state=101)),
    ])
    return pipeline

# %%
pipe = pipeline_adaboost_reg()
pipe.fit(X_train, y_train)

# 1. Get the fitted selector and its mask
selector = pipe.named_steps["feat_selection"]
support_mask = selector.get_support()              # boolean array
selected_features = X_train.columns[support_mask]  # names of selected features

print("Selected features:", list(selected_features))
# Out:
# Selected features: ['Close_lag1', 'Close_lag3', 'Close_lag5', 'Close_lag7', 'Close_lag21']

# %%
pipe = pipeline_adaboost_reg()
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('feat_scaling', StandardScaler()),
#                 ('feat_selection',
#                  SelectFromModel(estimator=RandomForestRegressor(random_state=101))),
#                 ('model', RandomForestRegressor(random_state=101))])

# %%
selector = pipe.named_steps["feat_selection"]
support_mask = selector.get_support()              # boolean array
selected_features = X_train.columns[support_mask]  # names of selected features

print("Selected features:", list(selected_features))
# Out:
# Selected features: ['Close_lag1', 'Close_lag3', 'Close_lag5', 'Close_lag7', 'Close_lag21']

# %%
import numpy as np
import pandas as pd

rf = selector.estimator_                          # the fitted RandomForestRegressor
importances = rf.feature_importances_             # array aligned with original columns

feat_imp = pd.DataFrame({
    "feature": X_train.columns,
    "importance": importances,
})

# Sort and take top 15
feat_imp = feat_imp.sort_values("importance", ascending=False)
top15 = feat_imp.head(15).copy()

# Percentage of total importance
total_imp = feat_imp["importance"].sum()
top15["importance_pct"] = 100 * top15["importance"] / total_imp

print(top15)
# Out:
#                                  feature  importance  importance_pct
# 58                            Close_lag1    0.866929       86.692934
# 59                            Close_lag3    0.067952        6.795241
# 63                           Close_lag21    0.023419        2.341908
# 60                            Close_lag5    0.016207        1.620718
# 61                            Close_lag7    0.015341        1.534070
# 62                           Close_lag14    0.001461        0.146072
# 8   Natural_Rate__of_Unemployment_(est.)    0.001293        0.129319
# 64                           Close_lag28    0.001159        0.115885
# 32                        M2_Money_Stock    0.001063        0.106311
# 31           30-Year_Fixed_Mortgage_Rate    0.000829        0.082853
# 38           CBOE_Volatility_Index (VIX)    0.000782        0.078206
# 6                   Producer_Price_Index    0.000778        0.077835
# 15             Core_CPI_(ex_Food/Energy)    0.000497        0.049729
# 51                    Price_Movement_Pct    0.000375        0.037478
# 55                           Day_of_Year    0.000374        0.037367

# %%
top15_names = set(top15["feature"])
selected_set = set(selected_features)

intersection = top15_names & selected_set
match_pct = 100 * len(intersection) / len(top15_names)

print("Overlap features:", intersection)
print("Match percentage:", match_pct)
# Out:
# Overlap features: {'Close_lag3', 'Close_lag1', 'Close_lag5', 'Close_lag7', 'Close_lag21'}
# Match percentage: 33.333333333333336
